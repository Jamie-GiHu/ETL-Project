# %% [markdown]
# # Code to extract TV info from Good Guys

# %%
# Dependencies
import requests
from bs4 import BeautifulSoup as bs

# %% [markdown]
# There are 136 televisions listed on the Good Guys website contained in 3 webpages (60 per page) OR 2 webpages (100 per page)

# %%
# URL of pages to be scraped

urls = list() # Create list of urls for loop

urls.append("https://www.thegoodguys.com.au/televisions/all-tvs#facet:&productBeginIndex:0&orderBy:&pageView:grid&minPrice:&maxPrice:&pageSize:60&") 
urls.append("https://www.thegoodguys.com.au/televisions/all-tvs#facet:&productBeginIndex:60&orderBy:&pageView:grid&minPrice:&maxPrice:&pageSize:60&")
urls.append("https://www.thegoodguys.com.au/televisions/all-tvs#facet:&productBeginIndex:120&orderBy:&pageView:grid&minPrice:&maxPrice:&pageSize:60&")

urls
# Out:
# ['https://www.thegoodguys.com.au/televisions/all-tvs#facet:&productBeginIndex:0&orderBy:&pageView:grid&minPrice:&maxPrice:&pageSize:60&',
#  'https://www.thegoodguys.com.au/televisions/all-tvs#facet:&productBeginIndex:60&orderBy:&pageView:grid&minPrice:&maxPrice:&pageSize:60&',
#  'https://www.thegoodguys.com.au/televisions/all-tvs#facet:&productBeginIndex:120&orderBy:&pageView:grid&minPrice:&maxPrice:&pageSize:60&']

# %%
# Create function to retrieve url page, create Beautiful Soup object, 
# parse and get results for loop.

def get_results(page_no): 

    # Retrieve page with the requests module
    response = requests.get(urls[page_no])

    # Create a Beautiful Soup object; parse with 'html.parser'
    soup = bs(response.text, "html.parser")

    # results are returned as an iterable list
    results = soup.select("#product_listing_tab")[0].find_all("li")
    
    return results
      
# Example: to find the Product Category for the first result
print(f"There are {len(get_results(1))} results on this page")
# Out:
# There are 60 results on this page

# %%
results = get_results(0)

# %% [markdown]
# ## Find Product Category

# %%
# Create function to get product category for loop

def category_finder(x):
    onclick = results[x].a["onclick"]
    start = onclick.rfind("Product Category L1 :") + len("Product Category L1 :")
    end = onclick.rfind("','TGGCATLPEventAction':'Product Category L2 :")
    category = onclick[start:end]
    return category

# Example: to find the Product Category for the first result
print(category_finder(0))
# Out:
# Televisions

# %% [markdown]
# ## Find Currency Code

# %%
# Create function to get currency code for loop

def currency_finder(x):
    scripts = results[x].script.find_next("script").string
    start = scripts.rfind("currencyCode")+len("currencyCode")+4
    end = start + 3
    currency = scripts[start:end]
    return currency

# Example: to find the Currency Code for the first result
print(currency_finder(0))
# Out:
# AUD

# %% [markdown]
# ## Find Brand

# %%
# Create function to get brand for loop

def brand_finder(x):
    brand = results[x].select('input[type="hidden"]')[3]["value"]
    return brand

# Example: to find the Brand for the first result
print(brand_finder(0))
# Out:
# Sony

# %% [markdown]
# ## Find Model Number

# %%
# Create function to get model number for loop

def model_finder(x):
    model = results[x].find("div", class_="product-tile-model").text
    return model

# Example: to find the Model Number for the first result
print(model_finder(0))
# Out:
# KDL32W660E

# %% [markdown]
# ## Find Name

# %%
# Create function to get name for loop

def name_finder(x):
    brand = results[x].select('input[type="hidden"]')[3]["value"]
    name = results[x].select('input[type="hidden"]')[4]["value"]
    return brand + " " + name

# Example: to find the Product Name for the first result
print(name_finder(0))
# Out:
# Sony 32"(81cm) FHD LED LCD Smart TV

# %% [markdown]
# ## Find Screen Size

# %%
# Create function to get screen size for loop

def size_finder(x):
    name = results[x].select('input[type="hidden"]')[4]["value"]
    size = name.split()[0]
    return size

# Example: to find the Screen Size for the first result
print(size_finder(0))
# Out:
# 32"(81cm)

# %% [markdown]
# ## Find Price

# %%
# Create function to get price for loop

def price_finder(x):
    price = results[x].select('input[type="hidden"]')[5]["value"]
    return price

# Example: to find the Price for the first result
print(price_finder(0))
# Out:
# $595.00

# %% [markdown]
# ## Find Link to Product Image

# %%
# Create function to get image link for loop

def image_finder(x):
    image = results[x].img["data-src"]
    return image

# Example: to find the link to Product Image for the first result
print(image_finder(0))
# Out:
# //thegoodguys.sirv.com/products/50048259/50048259_511653.PNG?scale.height=215&scale.width=215&canvas.height=215&canvas.width=215&canvas.opacity=0

# %% [markdown]
# ## The Loop

# %%
# Create lists to hold values

categories = list()
currencies = list()
brands = list()
models = list()
names = list()
sizes = list()
prices = list()
images = list()

# %%
# Loop through first set of returned results

x = 0

for x in range(len(results)):
    
    try:
        
        category = category_finder(x)
        currency = currency_finder(x)
        brand = brand_finder(x)
        model = model_finder(x)
        name = name_finder(x)
        size = size_finder(x)
        price = price_finder(x)
        image = image_finder(x)
        
        if (category and currency and brand and model and name and size and price and image):
            
                    categories.append(category)
                    currencies.append(currency)
                    brands.append(brand)
                    models.append(model)
                    names.append(name)
                    sizes.append(size)
                    prices.append(price)
                    images.append(image)
                    
    except:
        print("Price not available: ",name_finder(x))
            
    x += 1
# Out:
# Price not available:  FFALCON 32" F1 HD LED TV
# Price not available:  Sony 85" Z9G 8K UHD ANDROID LCD LED TV

# %%
# Check number of results - site lists 136 products in total

print(len(categories))
print(len(currencies))
print(len(brands))
print(len(names))
print(len(sizes))
print(len(prices))
print(len(images))
# Out:
# 58
# 58
# 58
# 58
# 58
# 58
# 58

# %%
len(results)
# Out:
# 60

# %%
print(names[0])
print(names[56])
# Out:
# Sony 32"(81cm) FHD LED LCD Smart TV
# LG 43" UN7300 4K UHD SMART LED TV

# %%
print(names[58])
print(names[115])
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-18-e77ebd60e532> in <module>
# ----> 1 print(names[58])
#       2 print(names[115])
#
# IndexError: list index out of range

# %%
import pandas as pd

df = pd.DataFrame({
        "category": "Televisions",
        "currency": currencies,
        "brand": brands,
        "model": models,
        "name": names,
        "size": size,
        "price": prices,
        "image": images
})

df
# Out:
#        category currency    brand           model  \
# 0   Televisions      AUD     Sony      KDL32W660E
# 1   Televisions      AUD      TCL        40D3000F
# 2   Televisions      AUD  Hitachi         32HDSM8
# 3   Televisions      AUD  Hitachi        65UHDSM8
# 4   Televisions      AUD  Hitachi        55UHDSM8
# 5   Televisions      AUD  Hitachi        50UHDSM8
# 6   Televisions      AUD  Hitachi        40FHDSM8
# 7   Televisions      AUD  Philips    55PUT6103/79
# 8   Televisions      AUD  Philips    50PUT6103/79
# 9   Televisions      AUD  Hisense         H100LDA
# 10  Televisions      AUD   Linsar     LS58UHDSM20
# 11  Televisions      AUD  FFALCON            24F1
# 12  Televisions      AUD  FFALCON            40F1
# 13  Televisions      AUD  FFALCON           50UF1
# 14  Televisions      AUD   Linsar         LS32CHD
# 15  Televisions      AUD   Linsar        LS40CFHD
# 16  Televisions      AUD     Sony         KD55A8G
# 17  Televisions      AUD     Sony         KD65A8G
# 18  Televisions      AUD     Sony         KD77A9G
# 19  Televisions      AUD      TCL          75P715
# 20  Televisions      AUD      TCL          55P715
# 21  Televisions      AUD      TCL          75X915
# 22  Televisions      AUD      TCL          75C815
# 23  Televisions      AUD      TCL          65P715
# 24  Televisions      AUD      TCL          50P715
# 25  Televisions      AUD  Samsung  QA43LS05TAWXXY
# 26  Televisions      AUD      TCL          43P715
# 27  Televisions      AUD      TCL           75X10
# 28  Televisions      AUD      TCL           65X10
# 29  Televisions      AUD  Samsung  VG-SCFT50BE/RU
# 30  Televisions      AUD      TCL          65X915
# 31  Televisions      AUD  FFALCON           55UF1
# 32  Televisions      AUD  FFALCON           65UF1
# 33  Televisions      AUD     GoTV        GTV-3200
# 25        Samsung 43" LS05 4K UHD SMART SERO QLED TV  49"  $1995.00
# 26               TCL 43" P715 4K QUHD ANDROID LED TV  49"   $695.00
# 27        TCL 75" X10 MINI LED 4K UHD ANDROID LED TV  49"  $6495.00
# 28        TCL 65" X10 MINI LED 4K UHD ANDROID LED TV  49"  $4495.00
# 29  Samsung Bezel Frame for 50" Frame TVs Beige Wood  49"   $149.00
# 30               TCL 65" X915 8K UHD ANDROID QLED TV  49"  $4295.00
# 31                      FFALCON 55" UF1 UHD SMART TV  49"   $699.00
# 32                      FFALCON 65" UF1 UHD SMART TV  49"   $899.00
# 33        GoTV 32" GTV3200 HD NON-SMART SOLAR LED TV  49"   $699.00
# 34            Samsung 43" TU8000 4K UHD SMART LED TV  49"   $895.00
# 35            Samsung 50" TU8000 4K UHD SMART LED TV  49"   $995.00
# 36            Samsung 55" TU8000 4K UHD SMART LED TV  49"  $1195.00
# 37            Samsung 75" TU8000 4K UHD SMART LED TV  49"  $2295.00
# 38            Samsung 82" TU8000 4K UHD SMART LED TV  49"  $3495.00
# 39             Samsung 55" Q60T 4K UHD SMART QLED TV  49"  $1495.00
# 40             Samsung 65" Q60T 4K UHD SMART QLED TV  49"  $1895.00
# 41             Samsung 75" Q60T 4K UHD SMART QLED TV  49"  $2895.00
# 42             Samsung 55" Q70T 4K UHD SMART QLED TV  49"  $1795.00
# 43             Samsung 65" Q70T 4K UHD SMART QLED TV  49"  $2295.00
# 44             Samsung 75" Q70T 4K UHD SMART QLED TV  49"  $3495.00
# 45             Samsung 85" Q70T 4K UHD SMART QLED TV  49"  $5495.00
# 46             Samsung 55" Q80T 4K UHD SMART QLED TV  49"  $2195.00
# 47             Samsung 65" Q80T 4K UHD SMART QLED TV  49"  $2995.00
# 48             Samsung 75" Q80T 4K UHD SMART QLED TV  49"  $4495.00
# 49                   FFALCON 32" SF1 HD SMART LED TV  49"   $249.00
# 50                  FFALCON 40" SF1 FHD SMART LED TV  49"   $349.00
# 51             Samsung 85" Q80T 4K UHD SMART QLED TV  49"  $6495.00
# 52             Samsung 65" Q95T 4K UHD SMART QLED TV  49"  $3995.00
# 53             Samsung 75" Q95T 4K UHD SMART QLED TV  49"  $5995.00
# 54                 LG 55" UN7300 4K UHD SMART LED TV  49"  $1195.00
# 55                 LG 50" UN7300 4K UHD SMART LED TV  49"   $995.00
# 56                 LG 43" UN7300 4K UHD SMART LED TV  49"   $895.00
# 57      Sony 49" X8000H 4K UHD ANDROID BRAVIA LED TV  49"  $1295.00
#
#                                                 image
# 0   //thegoodguys.sirv.com/products/50048259/50048...
# 1   //thegoodguys.sirv.com/products/50052593/50052...
# 2   //thegoodguys.sirv.com/products/50064547/50064...
# 3   //thegoodguys.sirv.com/products/50064544/50064...
# 4   //thegoodguys.sirv.com/products/50063085/50063...
# 5   //thegoodguys.sirv.com/products/50063086/50063...
# 6   //thegoodguys.sirv.com/products/50063088/50063...
# 7   //thegoodguys.sirv.com/products/50063013/50063...
# 8   //thegoodguys.sirv.com/products/50063014/50063...
# 9   //thegoodguys.sirv.com/products/50068151/50068...
# 10  //thegoodguys.sirv.com/products/50067473/50067...
# 11  //thegoodguys.sirv.com/products/50066203/50066...
# 12  //thegoodguys.sirv.com/products/50066208/50066...
# 13  //thegoodguys.sirv.com/products/50066211/50066...
# 14  //thegoodguys.sirv.com/products/50066633/50066...
# 15  //thegoodguys.sirv.com/products/50066636/50066...
# 16  //thegoodguys.sirv.com/products/50065308/50065...
# 17  //thegoodguys.sirv.com/products/50065310/50065...
# 18  //thegoodguys.sirv.com/products/50065351/50065...
# 19  //thegoodguys.sirv.com/products/50070879/50070...
# 20  //thegoodguys.sirv.com/products/50070880/50070...
# 21  //thegoodguys.sirv.com/products/50070881/50070...
# 22  //thegoodguys.sirv.com/products/50070882/50070...
# 23  //thegoodguys.sirv.com/products/50070884/50070...
# 24  //thegoodguys.sirv.com/products/50070885/50070...
# 25  //thegoodguys.sirv.com/products/50070373/50070...
# 26  //thegoodguys.sirv.com/products/50070887/50070...
# 27  //thegoodguys.sirv.com/products/50071363/50071...
# 28  //thegoodguys.sirv.com/products/50071364/50071...
# 29  //thegoodguys.sirv.com/products/50071566/50071...
# 30  //thegoodguys.sirv.com/products/50071366/50071...
# 31  //thegoodguys.sirv.com/products/50070685/50070...
# 32  //thegoodguys.sirv.com/products/50070686/50070...
# 33  //thegoodguys.sirv.com/products/50070358/50070...
# 34  //thegoodguys.sirv.com/products/50070363/50070...
# 35  //thegoodguys.sirv.com/products/50070364/50070...
# 36  //thegoodguys.sirv.com/products/50070365/50070...
# 37  //thegoodguys.sirv.com/products/50070369/50070...
# 38  //thegoodguys.sirv.com/products/50070370/50070...
# 39  //thegoodguys.sirv.com/products/50070374/50070...
# 40  //thegoodguys.sirv.com/products/50070375/50070...
# 41  //thegoodguys.sirv.com/products/50070376/50070...
# 42  //thegoodguys.sirv.com/products/50070377/50070...
# 43  //thegoodguys.sirv.com/products/50070378/50070...
# 44  //thegoodguys.sirv.com/products/50070379/50070...
# 45  //thegoodguys.sirv.com/products/50070380/50070...
# 46  //thegoodguys.sirv.com/products/50070381/50070...
# 47  //thegoodguys.sirv.com/products/50070382/50070...
# 48  //thegoodguys.sirv.com/products/50070383/50070...
# 49  //thegoodguys.sirv.com/products/50070859/50070...
# 50  //thegoodguys.sirv.com/products/50070860/50070...
# 51  //thegoodguys.sirv.com/products/50070384/50070...
# 52  //thegoodguys.sirv.com/products/50070385/50070...
# 53  //thegoodguys.sirv.com/products/50070386/50070...
# 54  //thegoodguys.sirv.com/products/50070525/50070...
# 55  //thegoodguys.sirv.com/products/50070526/50070...
# 56  //thegoodguys.sirv.com/products/50070527/50070...
# 57  //thegoodguys.sirv.com/products/50070589/50070...

# %%
df.describe()
# Out:
#            category currency    brand           model  \
# count            58       58       58              58
# unique            1        1       10              58
# top     Televisions      AUD  Samsung  UA50TU8000WXXY
# freq             58       58       20               1
#
#                                           name size    price  \
# count                                       58   58       58
# unique                                      58    1       39
# top     Samsung 82" TU8000 4K UHD SMART LED TV  49"  $699.00
# freq                                         1   58        4
#
#                                                     image
# count                                                  58
# unique                                                 58
# top     //thegoodguys.sirv.com/products/50065351/50065...
# freq                                                    1

# %%
df[df.duplicated()] # Page not refreshing when input new URL - need to fix
# Out:
# Empty DataFrame
# Columns: [category, currency, brand, model, name, size, price, image]
# Index: []

# %%
df.to_csv("output/good_guys.csv")
