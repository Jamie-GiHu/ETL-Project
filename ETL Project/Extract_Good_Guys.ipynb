# %% [markdown]
# # Code to extract TV info from Good Guys

# %%
# Dependencies
import requests
from bs4 import BeautifulSoup as bs

# %% [markdown]
# There are 136 televisions listed on the Good Guys website contained in 3 webpages (60 per page) OR 2 webpages (100 per page)

# %%
# URL of pages to be scraped

urls = list() # Create list of urls for loop

urls.append("https://www.thegoodguys.com.au/televisions/all-tvs#facet:&productBeginIndex:0&orderBy:&pageView:grid&minPrice:&maxPrice:&pageSize:60&") 
urls.append("https://www.thegoodguys.com.au/televisions/all-tvs#facet:&productBeginIndex:60&orderBy:&pageView:grid&minPrice:&maxPrice:&pageSize:60&")
urls.append("https://www.thegoodguys.com.au/televisions/all-tvs#facet:&productBeginIndex:120&orderBy:&pageView:grid&minPrice:&maxPrice:&pageSize:60&")

urls
# Out:
# ['https://www.thegoodguys.com.au/televisions/all-tvs#facet:&productBeginIndex:0&orderBy:&pageView:grid&minPrice:&maxPrice:&pageSize:60&',
#  'https://www.thegoodguys.com.au/televisions/all-tvs#facet:&productBeginIndex:60&orderBy:&pageView:grid&minPrice:&maxPrice:&pageSize:60&',
#  'https://www.thegoodguys.com.au/televisions/all-tvs#facet:&productBeginIndex:120&orderBy:&pageView:grid&minPrice:&maxPrice:&pageSize:60&']

# %%
# Create function to retrieve url page, create Beautiful Soup object, 
# parse and get results for loop.

def get_results(page_no): 

    # Retrieve page with the requests module
    response = requests.get(urls[page_no])

    # Create a Beautiful Soup object; parse with 'html.parser'
    soup = bs(response.text, "html.parser")

    # results are returned as an iterable list
    results = soup.select("#product_listing_tab")[0].find_all("li")
    
    return results
      
# Example: to find the Product Category for the first result
print(f"There are {len(get_results(1))} results on this page")
# Out:
# There are 60 results on this page

# %%
results = get_results(0)

# %% [markdown]
# ## Find Product Category

# %%
# Create function to get product category for loop

def category_finder(x):
    onclick = results[x].a["onclick"]
    start = onclick.rfind("Product Category L1 :") + len("Product Category L1 :")
    end = onclick.rfind("','TGGCATLPEventAction':'Product Category L2 :")
    category = onclick[start:end]
    return category

# Example: to find the Product Category for the first result
print(category_finder(0))
# Out:
# uctClick('50048259','32"(81cm) FHD LED LCD Smart TV','595.0','Sony','All TVs','','');

# %% [markdown]
# ## Find Currency Code

# %%
# Create function to get currency code for loop

def currency_finder(x):
    scripts = results[x].script.find_next("script").string
    start = scripts.rfind("currencyCode")+len("currencyCode")+4
    end = start + 3
    currency = scripts[start:end]
    return currency

# Example: to find the Currency Code for the first result
print(currency_finder(0))
# Out:
# AUD

# %% [markdown]
# ## Find Brand

# %%
# Create function to get brand for loop

def brand_finder(x):
    brand = results[x].select('input[type="hidden"]')[3]["value"]
    return brand

# Example: to find the Brand for the first result
print(brand_finder(0))
# Out:
# Sony

# %% [markdown]
# ## Find Name

# %%
# Create function to get name for loop

def name_finder(x):
    brand = results[x].select('input[type="hidden"]')[3]["value"]
    name = results[x].select('input[type="hidden"]')[4]["value"]
    return brand + " " + name

# Example: to find the Product Name for the first result
print(name_finder(0))
# Out:
# Sony 32"(81cm) FHD LED LCD Smart TV

# %% [markdown]
# ## Find Screen Size

# %%
# Create function to get screen size for loop

def size_finder(x):
    name = results[x].select('input[type="hidden"]')[4]["value"]
    size = name.split()[0]
    return size

# Example: to find the Screen Size for the first result
print(size_finder(0))
# Out:
# 32"(81cm)

# %% [markdown]
# ## Find Price

# %%
# Create function to get price for loop

def price_finder(x):
    price = results[x].select('input[type="hidden"]')[5]["value"]
    return price

# Example: to find the Price for the first result
print(price_finder(0))
# Out:
# $595.00

# %% [markdown]
# ## Find Link to Product Image

# %%
# Create function to get image link for loop

def image_finder(x):
    image = results[0].img["data-src"]
    return image

# Example: to find the link to Product Image for the first result
print(image_finder(0))
# Out:
# //thegoodguys.sirv.com/products/50048259/50048259_511653.PNG?scale.height=215&scale.width=215&canvas.height=215&canvas.width=215&canvas.opacity=0

# %% [markdown]
# ## The Loop

# %%
# Create lists to hold values

categories = list()
currencies = list()
brands = list()
names = list()
sizes = list()
prices = list()
images = list()

# %%
# Loop through first set of returned results

x = 0

for x in range(len(results)):
    
    try:
        
        category = category_finder(x)
        currency = currency_finder(x)
        brand = brand_finder(x)
        name = name_finder(x)
        size = size_finder(x)
        price = price_finder(x)
        image = image_finder(x)
        
        if (category and currency and brand and name and size and price and image):
            
                    categories.append(category)
                    currencies.append(currency)
                    brands.append(brand)
                    names.append(name)
                    sizes.append(size)
                    prices.append(price)
                    images.append(image)
                    
    except:
        print("Price not available: ",name_finder(x))
            
    x += 1
# Out:
# Price not available:  Hitachi 55"(140cm) UHD HDR LED LCD Smart TV
# Price not available:  FFALCON 32" F1 HD LED TV
# Price not available:  Sony 85" Z9G 8K UHD ANDROID LCD LED TV

# %%
# Check number of results - site lists 136 products in total

print(len(categories))
print(len(currencies))
print(len(brands))
print(len(names))
print(len(sizes))
print(len(prices))
print(len(images))
# Out:
# 57
# 57
# 57
# 57
# 57
# 57
# 57

# %%
len(results)
# Out:
# 60

# %%
print(names[0])
print(names[56])
# Out:
# Sony 32"(81cm) FHD LED LCD Smart TV
# TCL 32" S615 HD ANDROID LED TV

# %%
print(names[58])
print(names[115])
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-18-e77ebd60e532> in <module>
# ----> 1 print(names[58])
#       2 print(names[115])
#
# IndexError: list index out of range

# %%
import pandas as pd

df = pd.DataFrame({
        "category": "Televisions",
        "currency": currencies,
        "brand": brands,
        "name": names,
        "size": size,
        "price": prices,
        "image": images
})

df
# Out:
#        category currency    brand  \
# 0   Televisions      AUD     Sony
# 1   Televisions      AUD      TCL
# 2   Televisions      AUD  Hitachi
# 3   Televisions      AUD  Hitachi
# 4   Televisions      AUD  Hitachi
# 5   Televisions      AUD  Hitachi
# 6   Televisions      AUD  Philips
# 7   Televisions      AUD  Philips
# 8   Televisions      AUD   Linsar
# 9   Televisions      AUD  Hisense
# 10  Televisions      AUD     Sony
# 11  Televisions      AUD  FFALCON
# 12  Televisions      AUD  FFALCON
# 13  Televisions      AUD  FFALCON
# 14  Televisions      AUD     Sony
# 15  Televisions      AUD     Sony
# 16  Televisions      AUD   Linsar
# 17  Televisions      AUD   Linsar
# 18  Televisions      AUD       LG
# 19  Televisions      AUD       LG
# 20  Televisions      AUD       LG
# 21  Televisions      AUD  Samsung
# 22  Televisions      AUD  Samsung
# 23  Televisions      AUD  Samsung
# 24  Televisions      AUD  Philips
# 25  Televisions      AUD     Sony
# 26  Televisions      AUD     Sony
# 27  Televisions      AUD     Sony
# 28  Televisions      AUD  Samsung
# 29  Televisions      AUD  Samsung
# 30  Televisions      AUD  Hisense
# 31  Televisions      AUD  Hisense
# 32  Televisions      AUD  Hisense
# 33  Televisions      AUD  Hisense
# 34  Televisions      AUD  Hisense
# 35  Televisions      AUD  Hisense
# 36  Televisions      AUD  Hisense
# 37  Televisions      AUD  Hisense
# 38  Televisions      AUD  Samsung
# 39  Televisions      AUD  Samsung
# 40  Televisions      AUD  Hisense
# 41  Televisions      AUD  Hisense
# 42  Televisions      AUD  Hisense
# 43  Televisions      AUD  Samsung
# 44  Televisions      AUD  Hisense
# 45  Televisions      AUD  Samsung
# 46  Televisions      AUD  Samsung
# 47  Televisions      AUD  Samsung
# 48  Televisions      AUD  Samsung
# 49  Televisions      AUD  Samsung
# 50  Televisions      AUD  Samsung
# 51  Televisions      AUD  Samsung
# 52  Televisions      AUD  Hisense
# 53  Televisions      AUD      TCL
# 54  Televisions      AUD      TCL
# 55  Televisions      AUD      TCL
# 56  Televisions      AUD      TCL
#
#                                                 name size      price  \
# 0                Sony 32"(81cm) FHD LED LCD Smart TV  32"    $595.00
# 1                      TCL 40"(101cm) FHD LED LCD TV  32"    $445.00
# 2                        Hitachi 32" HD Smart LED TV  32"    $299.00
# 3                       Hitachi 65" UHD Smart LED TV  32"    $999.00
# 4            Hitachi 50"(127cm) UHD LED LCD Smart TV  32"    $699.00
# 5            Hitachi 40"(101cm) FHD LED LCD Smart TV  32"    $399.00
# 6            Philips 55"(140cm) UHD LED LCD Smart TV  32"    $699.00
# 7            Philips 50"(126cm) UHD LED LCD Smart TV  32"    $599.00
# 8                     Linsar 58" 4K UHD HDR Smart TV  32"    $599.00
# 9                 Hisense 100" 4K UHD SMART LASER TV  32"   $9995.00
# 10                 Sony 77" A9G 4K UHD SMART OLED TV  32"   $8495.00
# 11                          FFALCON 24" F1 HD LED TV  32"    $169.00
# 12                         FFALCON 40" F1 FHD LED TV  32"    $298.00
# 13                      FFALCON 50" UF1 UHD SMART TV  32"    $599.00
# 14               Sony 55" A8G 4K UHD Android OLED TV  32"   $2795.00
# 15               Sony 65" A8G 4K UHD Android OLED TV  32"   $4495.00
# 16                 Linsar 32" HD TV DVD Player Combo  32"    $279.00
# 17            Linsar 40" Full HD TV DVD Player Combo  32"    $369.00
# 18          LG 65" BX 4K UHD SMART ESSENTIAL OLED TV  32"   $3795.00
# 19          LG 55" BX 4K UHD SMART ESSENTIAL OLED TV  32"   $2795.00
# 20        LG 65" NANO99 8K UHD SMART NANOCELL LED TV  32"   $5495.00
# 21      Samsung Bezel Frame for 50" Frame TVs Walnut  32"    $149.00
# 22  Samsung Bezel Frame for 43" Frame TVs Beige Wood  32"    $129.00
# 23       Samsung Bezel Frame for 43" Frame TVs White  32"    $129.00
# 24                    Philips 32" PHT HD SLIM LED TV  32"    $219.00
# 25      Sony 55" X9500H 4K UHD ANDROID BRAVIA LED TV  32"   $2495.00
# 26      Sony 65" X9500H 4K UHD ANDROID BRAVIA LED TV  32"   $3495.00
# 27      Sony 75" X9500H 4K UHD ANDROID BRAVIA LED TV  32"   $4495.00
# 28       Samsung Bezel Frame for 50" Frame TVs White  32"    $149.00
# 29      Samsung Bezel Frame for 65" Frame TVs Walnut  32"    $179.00
# 30               Hisense 75" Q8 4K UHD SMART ULED TV  32"   $3495.00
# 31                Hisense 75" S8 4K UHD SMART LED TV  32"   $1895.00
# 32                Hisense 55" S8 4K UHD SMART LED TV  32"    $995.00
# 33               Hisense 65" Q8 4K UHD SMART ULED TV  32"   $1995.00
# 34                Hisense 65" S8 4K UHD SMART LED TV  32"   $1395.00
# 35                Hisense 50" S8 4K UHD SMART LED TV  32"    $795.00
# 36                Hisense 43" S8 4K UHD SMART LED TV  32"    $695.00
# 37               Hisense 55" Q8 4K UHD SMART ULED TV  32"   $1595.00
# 38  Samsung Bezel Frame for 65" Frame TVs Beige Wood  32"    $179.00
# 39       Samsung Bezel Frame for 65" Frame TVs White  32"    $179.00
# 40                   Hisense 49" S4 FHD SMART LED TV  32"    $595.00
# 41                   Hisense 40" S4 FHD SMART LED TV  32"    $495.00
# 42                    Hisense 32" S4 HD SMART LED TV  32"    $375.00
# 43       Samsung 55" LS01 4K UHD SMART SERIF QLED TV  32"   $1795.00
# 44                Hisense 85" S8 4K UHD SMART LED TV  32"   $3195.00
# 45      Samsung 43" LS03T 4K UHD SMART FRAME QLED TV  32"   $1395.00
# 46      Samsung 65" LS03T 4K UHD SMART FRAME QLED TV  32"   $2695.00
# 47      Samsung 50" LS03T 4K UHD SMART FRAME QLED TV  32"   $1695.00
# 48   Samsung 85" Q950T 8K UHD SMART INFINITY QLED TV  32"  $15995.00
# 49       Samsung 43" LS01 4K UHD SMART SERIF QLED TV  32"   $1295.00
# 50   Samsung 75" Q950T 8K UHD SMART INFINITY QLED TV  32"  $10995.00
# 51   Samsung 65" Q950T 8K UHD SMART INFINITY QLED TV  32"   $7995.00
# 52               Hisense 85" Q8 4K UHD SMART ULED TV  32"   $4995.00
# 53                   TCL 40" S615 FHD ANDROID LED TV  32"    $495.00
# 54       TCL 65" C815 4K PREMIUM UHD ANDROID QLED TV  32"   $1995.00
# 55       TCL 55" C815 4K PREMIUM UHD ANDROID QLED TV  32"   $1495.00
# 56                    TCL 32" S615 HD ANDROID LED TV  32"    $395.00
#
#                                                 image
# 0   //thegoodguys.sirv.com/products/50048259/50048...
# 1   //thegoodguys.sirv.com/products/50048259/50048...
# 2   //thegoodguys.sirv.com/products/50048259/50048...
# 3   //thegoodguys.sirv.com/products/50048259/50048...
# 4   //thegoodguys.sirv.com/products/50048259/50048...
# 5   //thegoodguys.sirv.com/products/50048259/50048...
# 6   //thegoodguys.sirv.com/products/50048259/50048...
# 7   //thegoodguys.sirv.com/products/50048259/50048...
# 8   //thegoodguys.sirv.com/products/50048259/50048...
# 9   //thegoodguys.sirv.com/products/50048259/50048...
# 10  //thegoodguys.sirv.com/products/50048259/50048...
# 11  //thegoodguys.sirv.com/products/50048259/50048...
# 12  //thegoodguys.sirv.com/products/50048259/50048...
# 13  //thegoodguys.sirv.com/products/50048259/50048...
# 14  //thegoodguys.sirv.com/products/50048259/50048...
# 15  //thegoodguys.sirv.com/products/50048259/50048...
# 16  //thegoodguys.sirv.com/products/50048259/50048...
# 17  //thegoodguys.sirv.com/products/50048259/50048...
# 18  //thegoodguys.sirv.com/products/50048259/50048...
# 19  //thegoodguys.sirv.com/products/50048259/50048...
# 20  //thegoodguys.sirv.com/products/50048259/50048...
# 21  //thegoodguys.sirv.com/products/50048259/50048...
# 22  //thegoodguys.sirv.com/products/50048259/50048...
# 23  //thegoodguys.sirv.com/products/50048259/50048...
# 24  //thegoodguys.sirv.com/products/50048259/50048...
# 25  //thegoodguys.sirv.com/products/50048259/50048...
# 26  //thegoodguys.sirv.com/products/50048259/50048...
# 27  //thegoodguys.sirv.com/products/50048259/50048...
# 28  //thegoodguys.sirv.com/products/50048259/50048...
# 29  //thegoodguys.sirv.com/products/50048259/50048...
# 30  //thegoodguys.sirv.com/products/50048259/50048...
# 31  //thegoodguys.sirv.com/products/50048259/50048...
# 32  //thegoodguys.sirv.com/products/50048259/50048...
# 33  //thegoodguys.sirv.com/products/50048259/50048...
# 34  //thegoodguys.sirv.com/products/50048259/50048...
# 35  //thegoodguys.sirv.com/products/50048259/50048...
# 36  //thegoodguys.sirv.com/products/50048259/50048...
# 37  //thegoodguys.sirv.com/products/50048259/50048...
# 38  //thegoodguys.sirv.com/products/50048259/50048...
# 39  //thegoodguys.sirv.com/products/50048259/50048...
# 40  //thegoodguys.sirv.com/products/50048259/50048...
# 41  //thegoodguys.sirv.com/products/50048259/50048...
# 42  //thegoodguys.sirv.com/products/50048259/50048...
# 43  //thegoodguys.sirv.com/products/50048259/50048...
# 44  //thegoodguys.sirv.com/products/50048259/50048...
# 45  //thegoodguys.sirv.com/products/50048259/50048...
# 46  //thegoodguys.sirv.com/products/50048259/50048...
# 47  //thegoodguys.sirv.com/products/50048259/50048...
# 48  //thegoodguys.sirv.com/products/50048259/50048...
# 49  //thegoodguys.sirv.com/products/50048259/50048...
# 50  //thegoodguys.sirv.com/products/50048259/50048...
# 51  //thegoodguys.sirv.com/products/50048259/50048...
# 52  //thegoodguys.sirv.com/products/50048259/50048...
# 53  //thegoodguys.sirv.com/products/50048259/50048...
# 54  //thegoodguys.sirv.com/products/50048259/50048...
# 55  //thegoodguys.sirv.com/products/50048259/50048...
# 56  //thegoodguys.sirv.com/products/50048259/50048...

# %%
df.describe()
# Out:
#            category currency    brand  \
# count            57       57       57
# unique            1        1        9
# top     Televisions      AUD  Samsung
# freq             57       57       15
#
#                                                    name size    price  \
# count                                                57   57       57
# unique                                               57    1       43
# top     Samsung 65" Q950T 8K UHD SMART INFINITY QLED TV  32"  $179.00
# freq                                                  1   57        3
#
#                                                     image
# count                                                  57
# unique                                                  1
# top     //thegoodguys.sirv.com/products/50048259/50048...
# freq                                                   57

# %%
df[df.duplicated()] # Page not refreshing when input new URL - need to fix
# Out:
# Empty DataFrame
# Columns: [category, currency, brand, name, size, price, image]
# Index: []

# %%
df.to_csv("output/good_guys.csv")
