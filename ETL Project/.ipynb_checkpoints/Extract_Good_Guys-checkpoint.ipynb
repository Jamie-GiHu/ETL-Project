# %% [markdown]
# # Code to extract TV info from Good Guys

# %%
# Dependencies
import requests
from bs4 import BeautifulSoup as bs

# %% [markdown]
# There are 136 televisions listed on the Good Guys website contained in 3 webpages (60 per page) OR 2 webpages (100 per page)

# %%
# URL of pages to be scraped

urls = list() # Create list of urls for loop

urls.append("https://www.thegoodguys.com.au/televisions/all-tvs#facet:&productBeginIndex:0&orderBy:&pageView:grid&minPrice:&maxPrice:&pageSize:60&") 
urls.append("https://www.thegoodguys.com.au/televisions/all-tvs#facet:&productBeginIndex:60&orderBy:&pageView:grid&minPrice:&maxPrice:&pageSize:60&")
urls.append("https://www.thegoodguys.com.au/televisions/all-tvs#facet:&productBeginIndex:120&orderBy:&pageView:grid&minPrice:&maxPrice:&pageSize:60&")

urls
# Out:
# ['https://www.thegoodguys.com.au/televisions/all-tvs#facet:&productBeginIndex:0&orderBy:&pageView:grid&minPrice:&maxPrice:&pageSize:60&',
#  'https://www.thegoodguys.com.au/televisions/all-tvs#facet:&productBeginIndex:60&orderBy:&pageView:grid&minPrice:&maxPrice:&pageSize:60&',
#  'https://www.thegoodguys.com.au/televisions/all-tvs#facet:&productBeginIndex:120&orderBy:&pageView:grid&minPrice:&maxPrice:&pageSize:60&']

# %%
# Create function to retrieve url page, create Beautiful Soup object, 
# parse and get results for loop.

def get_results(page_no): 

    # Retrieve page with the requests module
    response = requests.get(urls[page_no])

    # Create a Beautiful Soup object; parse with 'html.parser'
    soup = bs(response.text, "html.parser")

    # results are returned as an iterable list
    results = soup.select("#product_listing_tab")[0].find_all("li")
    
    return results
      
# Example: to find the Product Category for the first result
print(f"There are {len(get_results(1))} results on this page")
# Out:
# There are 60 results on this page

# %%
results = get_results(1)

# %% [markdown]
# ## Find Product Category

# %%
# Create function to get product category for loop

def category_finder(x):
    onclick = results[x].a["onclick"]
    start = onclick.rfind("Product Category L1 :") + len("Product Category L1 :")
    end = onclick.rfind("','TGGCATLPEventAction':'Product Category L2 :")
    category = onclick[start:end]
    return category

# Example: to find the Product Category for the first result
print(category_finder(0))
# Out:
# Televisions

# %% [markdown]
# ## Find Currency Code

# %%
# Create function to get currency code for loop

def currency_finder(x):
    scripts = results[x].script.find_next("script").string
    start = scripts.rfind("currencyCode")+len("currencyCode")+4
    end = start + 3
    currency = scripts[start:end]
    return currency

# Example: to find the Currency Code for the first result
print(currency_finder(0))
# Out:
# AUD

# %% [markdown]
# ## Find Brand

# %%
# Create function to get brand for loop

def brand_finder(x):
    brand = results[x].select('input[type="hidden"]')[3]["value"]
    return brand

# Example: to find the Brand for the first result
print(brand_finder(0))
# Out:
# Sony

# %% [markdown]
# ## Find Name

# %%
# Create function to get name for loop

def name_finder(x):
    brand = results[x].select('input[type="hidden"]')[3]["value"]
    name = results[x].select('input[type="hidden"]')[4]["value"]
    return brand + " " + name

# Example: to find the Product Name for the first result
print(name_finder(0))
# Out:
# Sony 32"(81cm) FHD LED LCD Smart TV

# %% [markdown]
# ## Find Screen Size

# %%
# Create function to get screen size for loop

def size_finder(x):
    name = results[x].select('input[type="hidden"]')[4]["value"]
    size = name.split()[0]
    return size

# Example: to find the Screen Size for the first result
print(size_finder(0))
# Out:
# 32"(81cm)

# %% [markdown]
# ## Find Price

# %%
# Create function to get price for loop

def price_finder(x):
    price = results[x].select('input[type="hidden"]')[5]["value"]
    return price

# Example: to find the Price for the first result
print(price_finder(0))
# Out:
# $595.00

# %% [markdown]
# ## Find Link to Product Image

# %%
# Create function to get image link for loop

def image_finder(x):
    image = results[0].img["data-src"]
    return image

# Example: to find the link to Product Image for the first result
print(image_finder(0))
# Out:
# //thegoodguys.sirv.com/products/50048259/50048259_511653.PNG?scale.height=215&scale.width=215&canvas.height=215&canvas.width=215&canvas.opacity=0

# %% [markdown]
# ## The Loop

# %%
# Create lists to hold values

categories = list()
currencies = list()
brands = list()
names = list()
sizes = list()
prices = list()
images = list()

# %%
# Loop through first set of returned results

x = 0

for x in range(len(results)):
    
    try:
        
        category = category_finder(x)
        currency = currency_finder(x)
        brand = brand_finder(x)
        name = name_finder(x)
        size = size_finder(x)
        price = price_finder(x)
        image = image_finder(x)
        
        if (category and currency and brand and name and size and price and image):
            
                    categories.append(category)
                    currencies.append(currency)
                    brands.append(brand)
                    names.append(name)
                    sizes.append(size)
                    prices.append(price)
                    images.append(image)
                    
    except:
        print("Price not available: ",name_finder(x))
            
    x += 1
# Out:
# Price not available:  FFALCON 32" F1 HD LED TV
# Price not available:  Sony 85" Z9G 8K UHD ANDROID LCD LED TV

# %%
# Check number of results - site lists 136 products in total

print(len(categories))
print(len(currencies))
print(len(brands))
print(len(names))
print(len(sizes))
print(len(prices))
print(len(images))
# Out:
# 116
# 116
# 116
# 116
# 116
# 116
# 116

# %%
len(results)
# Out:
# 60

# %%
print(names[0])
print(names[57])
# Out:
# Sony 32"(81cm) FHD LED LCD Smart TV
# TCL 32" S615 HD ANDROID LED TV

# %%
print(names[58])
print(names[115])
# Out:
# Sony 32"(81cm) FHD LED LCD Smart TV
# TCL 32" S615 HD ANDROID LED TV

# %%
import pandas as pd

df = pd.DataFrame({
        "category": "Televisions",
        "currency": currencies,
        "brand": brands,
        "name": names,
        "size": size,
        "price": prices,
        "image": images
})

df
# Out:
#         category currency    brand  \
# 0    Televisions      AUD     Sony
# 1    Televisions      AUD      TCL
# 2    Televisions      AUD  Hitachi
# 3    Televisions      AUD  Hitachi
# 4    Televisions      AUD  Hitachi
# ..           ...      ...      ...
# 111  Televisions      AUD  Hisense
# 112  Televisions      AUD      TCL
# 113  Televisions      AUD      TCL
# 114  Televisions      AUD      TCL
# 115  Televisions      AUD      TCL
#
#                                             name size     price  \
# 0            Sony 32"(81cm) FHD LED LCD Smart TV  32"   $595.00
# 1                  TCL 40"(101cm) FHD LED LCD TV  32"   $445.00
# 2                    Hitachi 32" HD Smart LED TV  32"   $299.00
# 3                   Hitachi 65" UHD Smart LED TV  32"   $999.00
# 4    Hitachi 55"(140cm) UHD HDR LED LCD Smart TV  32"   $695.00
# ..                                           ...  ...       ...
# 111          Hisense 85" Q8 4K UHD SMART ULED TV  32"  $4995.00
# 112              TCL 40" S615 FHD ANDROID LED TV  32"   $495.00
# 113  TCL 65" C815 4K PREMIUM UHD ANDROID QLED TV  32"  $1995.00
# 114  TCL 55" C815 4K PREMIUM UHD ANDROID QLED TV  32"  $1495.00
# 115               TCL 32" S615 HD ANDROID LED TV  32"   $395.00
#
#                                                  image
# 0    //thegoodguys.sirv.com/products/50048259/50048...
# 1    //thegoodguys.sirv.com/products/50048259/50048...
# 2    //thegoodguys.sirv.com/products/50048259/50048...
# 3    //thegoodguys.sirv.com/products/50048259/50048...
# 4    //thegoodguys.sirv.com/products/50048259/50048...
# ..                                                 ...
# 111  //thegoodguys.sirv.com/products/50048259/50048...
# 112  //thegoodguys.sirv.com/products/50048259/50048...
# 113  //thegoodguys.sirv.com/products/50048259/50048...
# 114  //thegoodguys.sirv.com/products/50048259/50048...
# 115  //thegoodguys.sirv.com/products/50048259/50048...
#
# [116 rows x 7 columns]

# %%
df.describe()
# Out:
#        currency    brand                                          name size  \
# count        58       58                                            58   58
# unique        1        9                                            58    1
# top         AUD  Samsung  Samsung Bezel Frame for 50" Frame TVs Walnut  32"
# freq         58       15                                             1   58
#
# 115                    TCL 32" S615 HD ANDROID LED TV  32"    $395.00
#
#                                                  image
# 58   //thegoodguys.sirv.com/products/50048259/50048...
# 59   //thegoodguys.sirv.com/products/50048259/50048...
# 60   //thegoodguys.sirv.com/products/50048259/50048...
# 61   //thegoodguys.sirv.com/products/50048259/50048...
# 62   //thegoodguys.sirv.com/products/50048259/50048...
# 63   //thegoodguys.sirv.com/products/50048259/50048...
# 64   //thegoodguys.sirv.com/products/50048259/50048...
# 65   //thegoodguys.sirv.com/products/50048259/50048...
# 66   //thegoodguys.sirv.com/products/50048259/50048...
# 67   //thegoodguys.sirv.com/products/50048259/50048...
# 68   //thegoodguys.sirv.com/products/50048259/50048...
# 69   //thegoodguys.sirv.com/products/50048259/50048...
# 70   //thegoodguys.sirv.com/products/50048259/50048...
# 71   //thegoodguys.sirv.com/products/50048259/50048...
# 72   //thegoodguys.sirv.com/products/50048259/50048...
# 73   //thegoodguys.sirv.com/products/50048259/50048...
# 74   //thegoodguys.sirv.com/products/50048259/50048...
# 75   //thegoodguys.sirv.com/products/50048259/50048...
# 76   //thegoodguys.sirv.com/products/50048259/50048...
# 77   //thegoodguys.sirv.com/products/50048259/50048...
# 78   //thegoodguys.sirv.com/products/50048259/50048...
# 79   //thegoodguys.sirv.com/products/50048259/50048...
# 80   //thegoodguys.sirv.com/products/50048259/50048...
# 81   //thegoodguys.sirv.com/products/50048259/50048...
# 82   //thegoodguys.sirv.com/products/50048259/50048...
# 83   //thegoodguys.sirv.com/products/50048259/50048...
# 84   //thegoodguys.sirv.com/products/50048259/50048...
# 85   //thegoodguys.sirv.com/products/50048259/50048...
# 86   //thegoodguys.sirv.com/products/50048259/50048...
# 87   //thegoodguys.sirv.com/products/50048259/50048...
# 88   //thegoodguys.sirv.com/products/50048259/50048...
# 89   //thegoodguys.sirv.com/products/50048259/50048...
# 90   //thegoodguys.sirv.com/products/50048259/50048...
# 91   //thegoodguys.sirv.com/products/50048259/50048...
# 92   //thegoodguys.sirv.com/products/50048259/50048...
# 93   //thegoodguys.sirv.com/products/50048259/50048...
# 94   //thegoodguys.sirv.com/products/50048259/50048...
# 95   //thegoodguys.sirv.com/products/50048259/50048...
# 96   //thegoodguys.sirv.com/products/50048259/50048...
# 97   //thegoodguys.sirv.com/products/50048259/50048...
# 98   //thegoodguys.sirv.com/products/50048259/50048...
# 99   //thegoodguys.sirv.com/products/50048259/50048...
# 100  //thegoodguys.sirv.com/products/50048259/50048...
# 101  //thegoodguys.sirv.com/products/50048259/50048...
# 102  //thegoodguys.sirv.com/products/50048259/50048...
# 103  //thegoodguys.sirv.com/products/50048259/50048...
# 104  //thegoodguys.sirv.com/products/50048259/50048...
# 105  //thegoodguys.sirv.com/products/50048259/50048...
# 106  //thegoodguys.sirv.com/products/50048259/50048...
# 107  //thegoodguys.sirv.com/products/50048259/50048...
# 108  //thegoodguys.sirv.com/products/50048259/50048...
# 109  //thegoodguys.sirv.com/products/50048259/50048...
# 110  //thegoodguys.sirv.com/products/50048259/50048...
# 111  //thegoodguys.sirv.com/products/50048259/50048...
# 112  //thegoodguys.sirv.com/products/50048259/50048...
# 113  //thegoodguys.sirv.com/products/50048259/50048...
# 114  //thegoodguys.sirv.com/products/50048259/50048...
# 115  //thegoodguys.sirv.com/products/50048259/50048...
