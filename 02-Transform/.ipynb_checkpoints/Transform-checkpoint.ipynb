# %% [markdown]
# # Code used to trasform csv to SQL database

# %%
# Dependencies
import pandas as pd
from sqlalchemy import create_engine

# %%
# Extract Goodguy's csv into a dataframe 
goodguys_file = "../01-Extract/output/good_guys.csv"
goodguys_df = pd.read_csv(goodguys_file)
goodguys_df.head()
# Out:
#    Unnamed: 0   retailer     category currency    brand       model  \
# 0           0  Good Guys  Televisions      AUD     Sony  KDL32W660E
# 1           1  Good Guys  Televisions      AUD      TCL    40D3000F
# 2           2  Good Guys  Televisions      AUD  Hitachi     32HDSM8
# 3           3  Good Guys  Televisions      AUD  Hitachi    65UHDSM8
# 4           4  Good Guys  Televisions      AUD  Hitachi    55UHDSM8
#
#                                           name        size    price  \
# 0          Sony 32"(81cm) FHD LED LCD Smart TV   32"(81cm)  $595.00
# 1                TCL 40"(101cm) FHD LED LCD TV  40"(101cm)  $445.00
# 2                  Hitachi 32" HD Smart LED TV         32"  $299.00
# 3                 Hitachi 65" UHD Smart LED TV         65"  $999.00
# 4  Hitachi 55"(140cm) UHD HDR LED LCD Smart TV  55"(140cm)  $695.00
#
#                                                image
# 0  //thegoodguys.sirv.com/products/50048259/50048...
# 1  //thegoodguys.sirv.com/products/50052593/50052...
# 2  //thegoodguys.sirv.com/products/50064547/50064...
# 3  //thegoodguys.sirv.com/products/50064544/50064...
# 4  //thegoodguys.sirv.com/products/50063085/50063...

# %%
# Extract Harvey norman's csv into a dataframe 
harvey_file = "../01-Extract/output/Extract_Harvey_Norman.csv"
harvey_df = pd.read_csv(harvey_file)
harvey_df.head()
# Out:
#    Unnamed: 0                                             Name  Price  \
# 0           6        Sony 65-inch X95H 4K UHD LED LCD Smart TV   2995
# 1           7           Hisense 65-inch S8 4K LED LCD Smart TV   1395
# 2           8  LG 55-inch Nano80 4K NanoCell Ai ThinQ Smart TV   1495
# 3           9           Hisense 75-inch S8 4K LED LCD Smart TV   1895
# 4          10                TCL 65-inch C715 4K QLED Smart TV   1695
#
#      Brand  Size   Model       Retailer   Categories Currencies  \
# 0     Sony    65    X95H  Harvey Norman  Televisions        AUD
# 1  Hisense    65      S8  Harvey Norman  Televisions        AUD
# 2       LG    55  Nano80  Harvey Norman  Televisions        AUD
# 3  Hisense    75      S8  Harvey Norman  Televisions        AUD
# 4      TCL    65    C715  Harvey Norman  Televisions        AUD
#
#                                                Image
# 0  https://azcd.harveynorman.com.au/media/catalog...
# 1  https://azcd.harveynorman.com.au/media/catalog...
# 2  https://azcd.harveynorman.com.au/media/catalog...
# 3  https://azcd.harveynorman.com.au/media/catalog...
# 4  https://azcd.harveynorman.com.au/media/catalog...

# %%
# Extract binglee's csv into a dataframe 
bing_lee_file = "../01-Extract/output/bing_lee.csv"
bing_lee_df = pd.read_csv(bing_lee_file)
bing_lee_df.head()
# Out:
#    Unnamed: 0  retailer     category currency    brand   model  \
# 0           0  Bing_Lee  Televisions      AUD      TCL  65P615
# 1           1  Bing_Lee  Televisions      AUD      TCL  75C815
# 2           2  Bing_Lee  Televisions      AUD  Hisense    40S4
# 3           3  Bing_Lee  Televisions      AUD  Hisense    49S4
# 4           4  Bing_Lee  Televisions      AUD      TCL  40S615
#
#                                          name  \
# 0       TCL - 65P615 - 65" UHD 4K Android TV
# 1          TCL - 75C815 - 75” QLED Android TV
# 2  Hisense - 40S4 - 40" Series 4 FHD Smart TV
# 3  Hisense - 49S4 - 49" Series 4 FHD Smart TV
# 4     TCL - 40S615 - 40” Full HD Android TV
#
#                                          size   price  \
# 0       TCL - 65P615 - 65" UHD 4K Android TV    995.0
# 1          TCL - 75C815 - 75” QLED Android TV  2995.0
# 2  Hisense - 40S4 - 40" Series 4 FHD Smart TV   495.0
# 3  Hisense - 49S4 - 49" Series 4 FHD Smart TV   595.0
# 4     TCL - 40S615 - 40” Full HD Android TV     495.0
#
#                                                image
# 0  https://media.binglee.com.au/media/catalog/pro...
# 1  https://media.binglee.com.au/media/catalog/pro...
# 2  https://media.binglee.com.au/media/catalog/pro...
# 3  https://media.binglee.com.au/media/catalog/pro...
# 4  https://media.binglee.com.au/media/catalog/pro...

# %%
# Dropping model duplicates and setting it to index 
goodguys_df.drop_duplicates("model", inplace=True)
goodguys_df.set_index("model", inplace=True)
goodguys_df.head()
# Out:
#             Unnamed: 0   retailer     category currency    brand  \
# model
# KDL32W660E           0  Good Guys  Televisions      AUD     Sony
# 40D3000F             1  Good Guys  Televisions      AUD      TCL
# 32HDSM8              2  Good Guys  Televisions      AUD  Hitachi
# 65UHDSM8             3  Good Guys  Televisions      AUD  Hitachi
# 55UHDSM8             4  Good Guys  Televisions      AUD  Hitachi
#
#                                                    name        size    price  \
# model
# KDL32W660E          Sony 32"(81cm) FHD LED LCD Smart TV   32"(81cm)  $595.00
# 40D3000F                  TCL 40"(101cm) FHD LED LCD TV  40"(101cm)  $445.00
# 32HDSM8                     Hitachi 32" HD Smart LED TV         32"  $299.00
# 65UHDSM8                   Hitachi 65" UHD Smart LED TV         65"  $999.00
# 55UHDSM8    Hitachi 55"(140cm) UHD HDR LED LCD Smart TV  55"(140cm)  $695.00
#
#                                                         image
# model
# KDL32W660E  //thegoodguys.sirv.com/products/50048259/50048...
# 40D3000F    //thegoodguys.sirv.com/products/50052593/50052...
# 32HDSM8     //thegoodguys.sirv.com/products/50064547/50064...
# 65UHDSM8    //thegoodguys.sirv.com/products/50064544/50064...
# 55UHDSM8    //thegoodguys.sirv.com/products/50063085/50063...

# %%
# Converting column names to lower case 
harvey_df.columns= harvey_df.columns.str.lower()
harvey_df.columns
# Out:
# Index(['unnamed: 0', 'name', 'price', 'brand', 'size', 'model', 'retailer',
#        'categories', 'currencies', 'image'],
#       dtype='object')

# %%
# Dropping model duplicates and setting it to index 
harvey_df.drop_duplicates("model", inplace=True)
harvey_df.set_index("model", inplace=True)
harvey_df.head()
# Out:
#         unnamed: 0                                             name  price  \
# model
# X95H             6        Sony 65-inch X95H 4K UHD LED LCD Smart TV   2995
# S8               7           Hisense 65-inch S8 4K LED LCD Smart TV   1395
# Nano80           8  LG 55-inch Nano80 4K NanoCell Ai ThinQ Smart TV   1495
# C715            10                TCL 65-inch C715 4K QLED Smart TV   1695
# Q60T            11            Samsung 75-inch Q60T 4K QLED Smart TV   2895
#
#           brand  size       retailer   categories currencies  \
# model
# X95H       Sony    65  Harvey Norman  Televisions        AUD
# S8      Hisense    65  Harvey Norman  Televisions        AUD
# Nano80       LG    55  Harvey Norman  Televisions        AUD
# C715        TCL    65  Harvey Norman  Televisions        AUD
# Q60T    Samsung    75  Harvey Norman  Televisions        AUD
#
#                                                     image
# model
# X95H    https://azcd.harveynorman.com.au/media/catalog...
# S8      https://azcd.harveynorman.com.au/media/catalog...
# Nano80  https://azcd.harveynorman.com.au/media/catalog...
# C715    https://azcd.harveynorman.com.au/media/catalog...
# Q60T    https://azcd.harveynorman.com.au/media/catalog...

# %%
# Dropping model duplicates and setting it to index 
bing_lee_df.drop_duplicates("model", inplace=True)
bing_lee_df.set_index("model", inplace=True)
bing_lee_df.shape
# Out:
# (134, 9)

# %%
# Convert size column to string 
bing_lee_df['size'] = bing_lee_df['size'].astype(str)

# %%
# Checking column types 
bing_lee_df.dtypes
# Out:
# Unnamed: 0      int64
# retailer       object
# category       object
# currency       object
# brand          object
# name           object
# size           object
# price         float64
# image          object
# dtype: object

# %%
# Extracting size from size column using regex
bing_lee_df['size'] = bing_lee_df['size'].str.extract('(\d\d\d?"|\d\d\d?”)', expand=False).str.strip()
bing_lee_df
# Out:
#             Unnamed: 0  retailer     category currency      brand  \
# model
# 65P615               0  Bing_Lee  Televisions      AUD        TCL
# 75C815               1  Bing_Lee  Televisions      AUD        TCL
# 40S4                 2  Bing_Lee  Televisions      AUD    Hisense
# 49S4                 3  Bing_Lee  Televisions      AUD    Hisense
# 40S615               4  Bing_Lee  Televisions      AUD        TCL
# ...                ...       ...          ...      ...        ...
# 55UH770T           129  Bing_Lee  Televisions      AUD         LG
# UD42C5600I         130  Bing_Lee  Televisions      AUD  Changhong
# QA98Q900RB         131  Bing_Lee  Televisions      AUD    Samsung
# TH65GX740A         132  Bing_Lee  Televisions      AUD  Panasonic
# 65R5               133  Bing_Lee  Televisions      AUD    Hisense
#
#                                                          name size    price  \
# model
# 65P615                  TCL - 65P615 - 65" UHD 4K Android TV   65"    995.0
# 75C815                     TCL - 75C815 - 75” QLED Android TV  75”   2995.0
# 40S4               Hisense - 40S4 - 40" Series 4 FHD Smart TV  40"    495.0
# 49S4               Hisense - 49S4 - 49" Series 4 FHD Smart TV  49"    595.0
# 40S615                TCL - 40S615 - 40” Full HD Android TV    40”    495.0
# ...                                                       ...  ...      ...
# 55UH770T                 LG - 55UH770T - 55" UHD Smart LED TV  55"   2249.0
# UD42C5600I          Changhong - UD42C5600I - 42" UHD Smart TV  42"    698.0
# QA98Q900RB  Samsung - QA98Q900RBWXXY - 98" QLED Smart 8K U...  98"  99999.0
# TH65GX740A   Panasonic - TH-65GX740A - 65" LED 4K UHD LED TV   65"   1295.0
# 65R5                Hisense - 65R5  - Series 5 65" UHD LED TV  65"    995.0
#
#                                                         image
# model
# 65P615      https://media.binglee.com.au/media/catalog/pro...
# 75C815      https://media.binglee.com.au/media/catalog/pro...
# 40S4        https://media.binglee.com.au/media/catalog/pro...
# 49S4        https://media.binglee.com.au/media/catalog/pro...
# 40S615      https://media.binglee.com.au/media/catalog/pro...
# ...                                                       ...
# 55UH770T    https://media.binglee.com.au/media/catalog/pro...
# UD42C5600I  https://media.binglee.com.au/media/catalog/pro...
# QA98Q900RB  https://media.binglee.com.au/media/catalog/pro...
# TH65GX740A  https://media.binglee.com.au/media/catalog/pro...
# 65R5        https://media.binglee.com.au/media/catalog/pro...
#
# [134 rows x 9 columns]

# %%
# Cleaning up unnecessary columns  
goodguys_transformed =goodguys_df.drop(columns=['Unnamed: 0'])
goodguys_transformed.head()
# Out:
#              retailer     category currency    brand  \
# model
# KDL32W660E  Good Guys  Televisions      AUD     Sony
# 40D3000F    Good Guys  Televisions      AUD      TCL
# 32HDSM8     Good Guys  Televisions      AUD  Hitachi
# 65UHDSM8    Good Guys  Televisions      AUD  Hitachi
# 55UHDSM8    Good Guys  Televisions      AUD  Hitachi
#
#                                                    name        size    price  \
# model
# KDL32W660E          Sony 32"(81cm) FHD LED LCD Smart TV   32"(81cm)  $595.00
# 40D3000F                  TCL 40"(101cm) FHD LED LCD TV  40"(101cm)  $445.00
# 32HDSM8                     Hitachi 32" HD Smart LED TV         32"  $299.00
# 65UHDSM8                   Hitachi 65" UHD Smart LED TV         65"  $999.00
# 55UHDSM8    Hitachi 55"(140cm) UHD HDR LED LCD Smart TV  55"(140cm)  $695.00
#
#                                                         image
# model
# KDL32W660E  //thegoodguys.sirv.com/products/50048259/50048...
# 40D3000F    //thegoodguys.sirv.com/products/50052593/50052...
# 32HDSM8     //thegoodguys.sirv.com/products/50064547/50064...
# 65UHDSM8    //thegoodguys.sirv.com/products/50064544/50064...
# 55UHDSM8    //thegoodguys.sirv.com/products/50063085/50063...

# %%
# Removing unnecessary symbols in column size 
goodguys_transformed['size'] = goodguys_transformed['size'].str.replace('"', " ")
goodguys_transformed
# Out:
#                  retailer     category currency    brand  \
# model
# KDL32W660E      Good Guys  Televisions      AUD     Sony
# 40D3000F        Good Guys  Televisions      AUD      TCL
# 32HDSM8         Good Guys  Televisions      AUD  Hitachi
# 65UHDSM8        Good Guys  Televisions      AUD  Hitachi
# 55UHDSM8        Good Guys  Televisions      AUD  Hitachi
# ...                   ...          ...      ...      ...
# 50QLEDSM20      Good Guys  Televisions      AUD  Hitachi
# 55QLEDSM20      Good Guys  Televisions      AUD  Hitachi
# 65QLEDSM20      Good Guys  Televisions      AUD  Hitachi
# QA32LS03TBWXXY  Good Guys  Televisions      AUD  Samsung
# 65P615          Good Guys  Televisions      AUD      TCL
#
#                                                         name        size  \
# model
# KDL32W660E               Sony 32"(81cm) FHD LED LCD Smart TV   32 (81cm)
# 40D3000F                       TCL 40"(101cm) FHD LED LCD TV  40 (101cm)
# 32HDSM8                          Hitachi 32" HD Smart LED TV         32
# 65UHDSM8                        Hitachi 65" UHD Smart LED TV         65
# 55UHDSM8         Hitachi 55"(140cm) UHD HDR LED LCD Smart TV  55 (140cm)
# ...                                                      ...         ...
# 50QLEDSM20           Hitachi 50" SM20 4K UHD ANDROID QLED TV         50
# 55QLEDSM20           Hitachi 55" SM20 4K UHD ANDROID QLED TV         55
# 65QLEDSM20           Hitachi 65" SM20 4K UHD ANDROID QLED TV         65
# QA32LS03TBWXXY  Samsung 32" LS03T 4K UHD SMART FRAME QLED TV         32
# 65P615                    TCL 65" P615 4K UHD ANDROID LED TV         65
#
#                    price                                              image
# model
# KDL32W660E       $595.00  //thegoodguys.sirv.com/products/50048259/50048...
# 40D3000F         $445.00  //thegoodguys.sirv.com/products/50052593/50052...
# 32HDSM8          $299.00  //thegoodguys.sirv.com/products/50064547/50064...
# 65UHDSM8         $999.00  //thegoodguys.sirv.com/products/50064544/50064...
# 55UHDSM8         $695.00  //thegoodguys.sirv.com/products/50063085/50063...
# ...                  ...                                                ...
# 50QLEDSM20       $899.00  //thegoodguys.sirv.com/products/50071408/50071...
# 55QLEDSM20      $1099.00  //thegoodguys.sirv.com/products/50071409/50071...
# 65QLEDSM20      $1499.00  //thegoodguys.sirv.com/products/50071410/50071...
# QA32LS03TBWXXY   $915.00  //thegoodguys.sirv.com/products/50072034/50072...
# 65P615           $995.00  //thegoodguys.sirv.com/products/50071986/50071...
#
# [131 rows x 8 columns]

# %%
# Removing cms measurement from size column   
goodguys_transformed['size'] = goodguys_transformed['size'].str.replace(r'\([^)]*\)', '').str.strip()
goodguys_transformed
# Out:
#                  retailer     category currency    brand  \
# model
# KDL32W660E      Good Guys  Televisions      AUD     Sony
# 40D3000F        Good Guys  Televisions      AUD      TCL
# 32HDSM8         Good Guys  Televisions      AUD  Hitachi
# 65UHDSM8        Good Guys  Televisions      AUD  Hitachi
# 55UHDSM8        Good Guys  Televisions      AUD  Hitachi
# ...                   ...          ...      ...      ...
# 50QLEDSM20      Good Guys  Televisions      AUD  Hitachi
# 55QLEDSM20      Good Guys  Televisions      AUD  Hitachi
# 65QLEDSM20      Good Guys  Televisions      AUD  Hitachi
# QA32LS03TBWXXY  Good Guys  Televisions      AUD  Samsung
# 65P615          Good Guys  Televisions      AUD      TCL
#
#                                                         name size     price  \
# model
# KDL32W660E               Sony 32"(81cm) FHD LED LCD Smart TV   32   $595.00
# 40D3000F                       TCL 40"(101cm) FHD LED LCD TV   40   $445.00
# 32HDSM8                          Hitachi 32" HD Smart LED TV   32   $299.00
# 65UHDSM8                        Hitachi 65" UHD Smart LED TV   65   $999.00
# 55UHDSM8         Hitachi 55"(140cm) UHD HDR LED LCD Smart TV   55   $695.00
# ...                                                      ...  ...       ...
# 50QLEDSM20           Hitachi 50" SM20 4K UHD ANDROID QLED TV   50   $899.00
# 55QLEDSM20           Hitachi 55" SM20 4K UHD ANDROID QLED TV   55  $1099.00
# 65QLEDSM20           Hitachi 65" SM20 4K UHD ANDROID QLED TV   65  $1499.00
# QA32LS03TBWXXY  Samsung 32" LS03T 4K UHD SMART FRAME QLED TV   32   $915.00
# 65P615                    TCL 65" P615 4K UHD ANDROID LED TV   65   $995.00
#
#                                                             image
# model
# KDL32W660E      //thegoodguys.sirv.com/products/50048259/50048...
# 40D3000F        //thegoodguys.sirv.com/products/50052593/50052...
# 32HDSM8         //thegoodguys.sirv.com/products/50064547/50064...
# 65UHDSM8        //thegoodguys.sirv.com/products/50064544/50064...
# 55UHDSM8        //thegoodguys.sirv.com/products/50063085/50063...
# ...                                                           ...
# 50QLEDSM20      //thegoodguys.sirv.com/products/50071408/50071...
# 55QLEDSM20      //thegoodguys.sirv.com/products/50071409/50071...
# 65QLEDSM20      //thegoodguys.sirv.com/products/50071410/50071...
# QA32LS03TBWXXY  //thegoodguys.sirv.com/products/50072034/50072...
# 65P615          //thegoodguys.sirv.com/products/50071986/50071...
#
# [131 rows x 8 columns]

# %%
# Cleaning up unnecessary columns  
harvey_transformed =harvey_df.drop(columns=['unnamed: 0'])
harvey_transformed.head()
# Out:
#                                                    name  price    brand  size  \
# model
# X95H          Sony 65-inch X95H 4K UHD LED LCD Smart TV   2995     Sony    65
# S8               Hisense 65-inch S8 4K LED LCD Smart TV   1395  Hisense    65
# Nano80  LG 55-inch Nano80 4K NanoCell Ai ThinQ Smart TV   1495       LG    55
# C715                  TCL 65-inch C715 4K QLED Smart TV   1695      TCL    65
# Q60T              Samsung 75-inch Q60T 4K QLED Smart TV   2895  Samsung    75
#
#              retailer   categories currencies  \
# model
# X95H    Harvey Norman  Televisions        AUD
# S8      Harvey Norman  Televisions        AUD
# Nano80  Harvey Norman  Televisions        AUD
# C715    Harvey Norman  Televisions        AUD
# Q60T    Harvey Norman  Televisions        AUD
#
#                                                     image
# model
# X95H    https://azcd.harveynorman.com.au/media/catalog...
# S8      https://azcd.harveynorman.com.au/media/catalog...
# Nano80  https://azcd.harveynorman.com.au/media/catalog...
# C715    https://azcd.harveynorman.com.au/media/catalog...
# Q60T    https://azcd.harveynorman.com.au/media/catalog...

# %%
# Renaming columns to match when joining 
harvey_transformed.rename(columns = {'categories':'category', 'currencies':'currency'}, inplace = True)
harvey_transformed.shape
# Out:
# (19, 8)

# %%
# Cleaning up unnecessary columns  
bing_lee_transformed =bing_lee_df.drop(columns=['Unnamed: 0'])
bing_lee_transformed.head()
# Out:
#         retailer     category currency    brand  \
# model
# 65P615  Bing_Lee  Televisions      AUD      TCL
# 75C815  Bing_Lee  Televisions      AUD      TCL
# 40S4    Bing_Lee  Televisions      AUD  Hisense
# 49S4    Bing_Lee  Televisions      AUD  Hisense
# 40S615  Bing_Lee  Televisions      AUD      TCL
#
#                                               name size   price  \
# model
# 65P615       TCL - 65P615 - 65" UHD 4K Android TV   65"   995.0
# 75C815          TCL - 75C815 - 75” QLED Android TV  75”  2995.0
# 40S4    Hisense - 40S4 - 40" Series 4 FHD Smart TV  40"   495.0
# 49S4    Hisense - 49S4 - 49" Series 4 FHD Smart TV  49"   595.0
# 40S615     TCL - 40S615 - 40” Full HD Android TV    40”   495.0
#
#                                                     image
# model
# 65P615  https://media.binglee.com.au/media/catalog/pro...
# 75C815  https://media.binglee.com.au/media/catalog/pro...
# 40S4    https://media.binglee.com.au/media/catalog/pro...
# 49S4    https://media.binglee.com.au/media/catalog/pro...
# 40S615  https://media.binglee.com.au/media/catalog/pro...

# %%
# Dropping null values 
bing_lee_transformed.dropna()
# Out:
#             retailer     category currency      brand  \
# model
# 65P615      Bing_Lee  Televisions      AUD        TCL
# 75C815      Bing_Lee  Televisions      AUD        TCL
# 40S4        Bing_Lee  Televisions      AUD    Hisense
# 49S4        Bing_Lee  Televisions      AUD    Hisense
# 40S615      Bing_Lee  Televisions      AUD        TCL
# ...              ...          ...      ...        ...
# 55UH770T    Bing_Lee  Televisions      AUD         LG
# UD42C5600I  Bing_Lee  Televisions      AUD  Changhong
# QA98Q900RB  Bing_Lee  Televisions      AUD    Samsung
# TH65GX740A  Bing_Lee  Televisions      AUD  Panasonic
# 65R5        Bing_Lee  Televisions      AUD    Hisense
#
#                                                          name size    price  \
# model
# 65P615                  TCL - 65P615 - 65" UHD 4K Android TV   65"    995.0
# 75C815                     TCL - 75C815 - 75” QLED Android TV  75”   2995.0
# 40S4               Hisense - 40S4 - 40" Series 4 FHD Smart TV  40"    495.0
# 49S4               Hisense - 49S4 - 49" Series 4 FHD Smart TV  49"    595.0
# 40S615                TCL - 40S615 - 40” Full HD Android TV    40”    495.0
# ...                                                       ...  ...      ...
# 55UH770T                 LG - 55UH770T - 55" UHD Smart LED TV  55"   2249.0
# UD42C5600I          Changhong - UD42C5600I - 42" UHD Smart TV  42"    698.0
# QA98Q900RB  Samsung - QA98Q900RBWXXY - 98" QLED Smart 8K U...  98"  99999.0
# TH65GX740A   Panasonic - TH-65GX740A - 65" LED 4K UHD LED TV   65"   1295.0
# 65R5                Hisense - 65R5  - Series 5 65" UHD LED TV  65"    995.0
#
#                                                         image
# model
# 65P615      https://media.binglee.com.au/media/catalog/pro...
# 75C815      https://media.binglee.com.au/media/catalog/pro...
# 40S4        https://media.binglee.com.au/media/catalog/pro...
# 49S4        https://media.binglee.com.au/media/catalog/pro...
# 40S615      https://media.binglee.com.au/media/catalog/pro...
# ...                                                       ...
# 55UH770T    https://media.binglee.com.au/media/catalog/pro...
# UD42C5600I  https://media.binglee.com.au/media/catalog/pro...
# QA98Q900RB  https://media.binglee.com.au/media/catalog/pro...
# TH65GX740A  https://media.binglee.com.au/media/catalog/pro...
# 65R5        https://media.binglee.com.au/media/catalog/pro...
#
# [129 rows x 8 columns]

# %%
# Removing unnecessary symbols 
bing_lee_transformed['size'] = bing_lee_transformed['size'].str.replace('"', " ")
bing_lee_transformed
# Out:
#             retailer     category currency      brand  \
# model
# 65P615      Bing_Lee  Televisions      AUD        TCL
# 75C815      Bing_Lee  Televisions      AUD        TCL
# 40S4        Bing_Lee  Televisions      AUD    Hisense
# 49S4        Bing_Lee  Televisions      AUD    Hisense
# 40S615      Bing_Lee  Televisions      AUD        TCL
# ...              ...          ...      ...        ...
# 55UH770T    Bing_Lee  Televisions      AUD         LG
# UD42C5600I  Bing_Lee  Televisions      AUD  Changhong
# QA98Q900RB  Bing_Lee  Televisions      AUD    Samsung
# TH65GX740A  Bing_Lee  Televisions      AUD  Panasonic
# 65R5        Bing_Lee  Televisions      AUD    Hisense
#
#                                                          name size    price  \
# model
# 65P615                  TCL - 65P615 - 65" UHD 4K Android TV   65     995.0
# 75C815                     TCL - 75C815 - 75” QLED Android TV  75”   2995.0
# 40S4               Hisense - 40S4 - 40" Series 4 FHD Smart TV  40     495.0
# 49S4               Hisense - 49S4 - 49" Series 4 FHD Smart TV  49     595.0
# 40S615                TCL - 40S615 - 40” Full HD Android TV    40”    495.0
# ...                                                       ...  ...      ...
# 55UH770T                 LG - 55UH770T - 55" UHD Smart LED TV  55    2249.0
# UD42C5600I          Changhong - UD42C5600I - 42" UHD Smart TV  42     698.0
# QA98Q900RB  Samsung - QA98Q900RBWXXY - 98" QLED Smart 8K U...  98   99999.0
# TH65GX740A   Panasonic - TH-65GX740A - 65" LED 4K UHD LED TV   65    1295.0
# 65R5                Hisense - 65R5  - Series 5 65" UHD LED TV  65     995.0
#
#                                                         image
# model
# 65P615      https://media.binglee.com.au/media/catalog/pro...
# 75C815      https://media.binglee.com.au/media/catalog/pro...
# 40S4        https://media.binglee.com.au/media/catalog/pro...
# 49S4        https://media.binglee.com.au/media/catalog/pro...
# 40S615      https://media.binglee.com.au/media/catalog/pro...
# ...                                                       ...
# 55UH770T    https://media.binglee.com.au/media/catalog/pro...
# UD42C5600I  https://media.binglee.com.au/media/catalog/pro...
# QA98Q900RB  https://media.binglee.com.au/media/catalog/pro...
# TH65GX740A  https://media.binglee.com.au/media/catalog/pro...
# 65R5        https://media.binglee.com.au/media/catalog/pro...
#
# [134 rows x 8 columns]

# %%
# Removing unnecessary symbols 
bing_lee_transformed['size'] = bing_lee_transformed['size'].str.strip('”')
bing_lee_transformed
# Out:
#             retailer     category currency      brand  \
# model
# 65P615      Bing_Lee  Televisions      AUD        TCL
# 75C815      Bing_Lee  Televisions      AUD        TCL
# 40S4        Bing_Lee  Televisions      AUD    Hisense
# 49S4        Bing_Lee  Televisions      AUD    Hisense
# 40S615      Bing_Lee  Televisions      AUD        TCL
# ...              ...          ...      ...        ...
# 55UH770T    Bing_Lee  Televisions      AUD         LG
# UD42C5600I  Bing_Lee  Televisions      AUD  Changhong
# QA98Q900RB  Bing_Lee  Televisions      AUD    Samsung
# TH65GX740A  Bing_Lee  Televisions      AUD  Panasonic
# 65R5        Bing_Lee  Televisions      AUD    Hisense
#
#                                                          name size    price  \
# model
# 65P615                  TCL - 65P615 - 65" UHD 4K Android TV   65     995.0
# 75C815                     TCL - 75C815 - 75” QLED Android TV   75   2995.0
# 40S4               Hisense - 40S4 - 40" Series 4 FHD Smart TV  40     495.0
# 49S4               Hisense - 49S4 - 49" Series 4 FHD Smart TV  49     595.0
# 40S615                TCL - 40S615 - 40” Full HD Android TV     40    495.0
# ...                                                       ...  ...      ...
# 55UH770T                 LG - 55UH770T - 55" UHD Smart LED TV  55    2249.0
# UD42C5600I          Changhong - UD42C5600I - 42" UHD Smart TV  42     698.0
# QA98Q900RB  Samsung - QA98Q900RBWXXY - 98" QLED Smart 8K U...  98   99999.0
# TH65GX740A   Panasonic - TH-65GX740A - 65" LED 4K UHD LED TV   65    1295.0
# 65R5                Hisense - 65R5  - Series 5 65" UHD LED TV  65     995.0
#
#                                                         image
# model
# 65P615      https://media.binglee.com.au/media/catalog/pro...
# 75C815      https://media.binglee.com.au/media/catalog/pro...
# 40S4        https://media.binglee.com.au/media/catalog/pro...
# 49S4        https://media.binglee.com.au/media/catalog/pro...
# 40S615      https://media.binglee.com.au/media/catalog/pro...
# ...                                                       ...
# 55UH770T    https://media.binglee.com.au/media/catalog/pro...
# UD42C5600I  https://media.binglee.com.au/media/catalog/pro...
# QA98Q900RB  https://media.binglee.com.au/media/catalog/pro...
# TH65GX740A  https://media.binglee.com.au/media/catalog/pro...
# 65R5        https://media.binglee.com.au/media/catalog/pro...
#
# [134 rows x 8 columns]

# %%
# Joining all dataframes 
tv_details = pd.concat([bing_lee_transformed, goodguys_transformed], ignore_index=False)
tv_details
# Out:
#                  retailer     category currency    brand  \
# model
# 65P615           Bing_Lee  Televisions      AUD      TCL
# 75C815           Bing_Lee  Televisions      AUD      TCL
# 40S4             Bing_Lee  Televisions      AUD  Hisense
# 49S4             Bing_Lee  Televisions      AUD  Hisense
# 40S615           Bing_Lee  Televisions      AUD      TCL
# ...                   ...          ...      ...      ...
# 50QLEDSM20      Good Guys  Televisions      AUD  Hitachi
# 55QLEDSM20      Good Guys  Televisions      AUD  Hitachi
# 65QLEDSM20      Good Guys  Televisions      AUD  Hitachi
# QA32LS03TBWXXY  Good Guys  Televisions      AUD  Samsung
# 65P615          Good Guys  Televisions      AUD      TCL
#
#                                                         name size     price  \
# model
# 65P615                 TCL - 65P615 - 65" UHD 4K Android TV   65        995
# 75C815                    TCL - 75C815 - 75” QLED Android TV   75      2995
# 40S4              Hisense - 40S4 - 40" Series 4 FHD Smart TV  40        495
# 49S4              Hisense - 49S4 - 49" Series 4 FHD Smart TV  49        595
# 40S615               TCL - 40S615 - 40” Full HD Android TV     40       495
# ...                                                      ...  ...       ...
# 50QLEDSM20           Hitachi 50" SM20 4K UHD ANDROID QLED TV   50   $899.00
# 55QLEDSM20           Hitachi 55" SM20 4K UHD ANDROID QLED TV   55  $1099.00
# 65QLEDSM20           Hitachi 65" SM20 4K UHD ANDROID QLED TV   65  $1499.00
# QA32LS03TBWXXY  Samsung 32" LS03T 4K UHD SMART FRAME QLED TV   32   $915.00
# 65P615                    TCL 65" P615 4K UHD ANDROID LED TV   65   $995.00
#
#                                                             image
# model
# 65P615          https://media.binglee.com.au/media/catalog/pro...
# 75C815          https://media.binglee.com.au/media/catalog/pro...
# 40S4            https://media.binglee.com.au/media/catalog/pro...
# 49S4            https://media.binglee.com.au/media/catalog/pro...
# 40S615          https://media.binglee.com.au/media/catalog/pro...
# ...                                                           ...
# 50QLEDSM20      //thegoodguys.sirv.com/products/50071408/50071...
# 55QLEDSM20      //thegoodguys.sirv.com/products/50071409/50071...
# 65QLEDSM20      //thegoodguys.sirv.com/products/50071410/50071...
# QA32LS03TBWXXY  //thegoodguys.sirv.com/products/50072034/50072...
# 65P615          //thegoodguys.sirv.com/products/50071986/50071...
#
# [265 rows x 8 columns]

# %%
# Joining all dataframes 
tv_details = pd.concat([tv_details, harvey_transformed], ignore_index=False)
tv_details
# Out:
#              retailer     category currency    brand  \
# model
# 65P615       Bing_Lee  Televisions      AUD      TCL
# 75C815       Bing_Lee  Televisions      AUD      TCL
# 40S4         Bing_Lee  Televisions      AUD  Hisense
# 49S4         Bing_Lee  Televisions      AUD  Hisense
# 40S615       Bing_Lee  Televisions      AUD      TCL
# ...               ...          ...      ...      ...
# Nano91  Harvey Norman  Televisions      AUD       LG
# Nano95  Harvey Norman  Televisions      AUD       LG
# Q8      Harvey Norman  Televisions      AUD  Hisense
# Q950T   Harvey Norman  Televisions      AUD  Samsung
# P715    Harvey Norman  Televisions      AUD      TCL
#
#                                                    name size  price  \
# model
# 65P615            TCL - 65P615 - 65" UHD 4K Android TV   65     995
# 75C815               TCL - 75C815 - 75” QLED Android TV   75   2995
# 40S4         Hisense - 40S4 - 40" Series 4 FHD Smart TV  40     495
# 49S4         Hisense - 49S4 - 49" Series 4 FHD Smart TV  49     595
# 40S615          TCL - 40S615 - 40” Full HD Android TV     40    495
# ...                                                 ...  ...    ...
# Nano91  LG 65-inch Nano91 4K NanoCell Ai ThinQ Smart TV   65   2695
# Nano95  LG 65-inch Nano95 8K NanoCell Ai ThinQ Smart TV   65   3995
# Q8                  Hisense 75-inch Q8 4K ULED Smart TV   75   3495
# Q950T            Samsung 85-inch Q950T 8K QLED Smart TV   85  12995
# P715            TCL 100-inch P715 QUHD LED LCD Smart TV  100  12995
#
#                                                     image
# model
# 65P615  https://media.binglee.com.au/media/catalog/pro...
# 75C815  https://media.binglee.com.au/media/catalog/pro...
# 40S4    https://media.binglee.com.au/media/catalog/pro...
# 49S4    https://media.binglee.com.au/media/catalog/pro...
# 40S615  https://media.binglee.com.au/media/catalog/pro...
# ...                                                   ...
# Nano91  https://azcd.harveynorman.com.au/media/catalog...
# Nano95  https://azcd.harveynorman.com.au/media/catalog...
# Q8      https://azcd.harveynorman.com.au/media/catalog...
# Q950T   https://azcd.harveynorman.com.au/media/catalog...
# P715    https://azcd.harveynorman.com.au/media/catalog...
#
# [284 rows x 8 columns]

# %% [markdown]
# ## Normalising Dataframes

# %%
#Converting columns in the dataframe to separate tables to be saved as csv 
def convert_column_to_fk(df, column, output_dir):
    values = sorted(list(df[column].unique()))
    ids = range(1, len(values) + 1)    
    fk_df = pd.DataFrame(values, index = ids).reset_index()
    fk_df.columns = ["id", column]
    fk_df.to_csv(f"{output_dir}/{column}.csv", index = False)
    df[column] = df[column].replace(dict(zip(values, ids)))
    df = df.rename(columns = {column: f"{column}_id"})
    return df

# %%
convert_column_to_fk(tv_details,"retailer","output")
# Out:
#         retailer_id     category currency    brand  \
# model
# 65P615            1  Televisions      AUD      TCL
# 75C815            1  Televisions      AUD      TCL
# 40S4              1  Televisions      AUD  Hisense
# 49S4              1  Televisions      AUD  Hisense
# 40S615            1  Televisions      AUD      TCL
# ...             ...          ...      ...      ...
# Nano91            3  Televisions      AUD       LG
# Nano95            3  Televisions      AUD       LG
# Q8                3  Televisions      AUD  Hisense
# Q950T             3  Televisions      AUD  Samsung
# P715              3  Televisions      AUD      TCL
#
#                                                    name size  price  \
# model
# 65P615            TCL - 65P615 - 65" UHD 4K Android TV   65     995
# 75C815               TCL - 75C815 - 75” QLED Android TV   75   2995
# 40S4         Hisense - 40S4 - 40" Series 4 FHD Smart TV  40     495
# 49S4         Hisense - 49S4 - 49" Series 4 FHD Smart TV  49     595
# 40S615          TCL - 40S615 - 40” Full HD Android TV     40    495
# ...                                                 ...  ...    ...
# Nano91  LG 65-inch Nano91 4K NanoCell Ai ThinQ Smart TV   65   2695
# Nano95  LG 65-inch Nano95 8K NanoCell Ai ThinQ Smart TV   65   3995
# Q8                  Hisense 75-inch Q8 4K ULED Smart TV   75   3495
# Q950T            Samsung 85-inch Q950T 8K QLED Smart TV   85  12995
# P715            TCL 100-inch P715 QUHD LED LCD Smart TV  100  12995
#
#                                                     image
# model
# 65P615  https://media.binglee.com.au/media/catalog/pro...
# 75C815  https://media.binglee.com.au/media/catalog/pro...
# 40S4    https://media.binglee.com.au/media/catalog/pro...
# 49S4    https://media.binglee.com.au/media/catalog/pro...
# 40S615  https://media.binglee.com.au/media/catalog/pro...
# ...                                                   ...
# Nano91  https://azcd.harveynorman.com.au/media/catalog...
# Nano95  https://azcd.harveynorman.com.au/media/catalog...
# Q8      https://azcd.harveynorman.com.au/media/catalog...
# Q950T   https://azcd.harveynorman.com.au/media/catalog...
# P715    https://azcd.harveynorman.com.au/media/catalog...
#
# [284 rows x 8 columns]

# %%
convert_column_to_fk(tv_details,"brand","output")
# Out:
#         retailer     category currency  brand_id  \
# model
# 65P615         1  Televisions      AUD        15
# 75C815         1  Televisions      AUD        15
# 40S4           1  Televisions      AUD         7
# 49S4           1  Televisions      AUD         7
# 40S615         1  Televisions      AUD        15
# ...          ...          ...      ...       ...
# Nano91         3  Televisions      AUD         9
# Nano95         3  Televisions      AUD         9
# Q8             3  Televisions      AUD         7
# Q950T          3  Televisions      AUD        13
# P715           3  Televisions      AUD        15
#
#                                                    name size  price  \
# model
# 65P615            TCL - 65P615 - 65" UHD 4K Android TV   65     995
# 75C815               TCL - 75C815 - 75” QLED Android TV   75   2995
# 40S4         Hisense - 40S4 - 40" Series 4 FHD Smart TV  40     495
# 49S4         Hisense - 49S4 - 49" Series 4 FHD Smart TV  49     595
# 40S615          TCL - 40S615 - 40” Full HD Android TV     40    495
# ...                                                 ...  ...    ...
# Nano91  LG 65-inch Nano91 4K NanoCell Ai ThinQ Smart TV   65   2695
# Nano95  LG 65-inch Nano95 8K NanoCell Ai ThinQ Smart TV   65   3995
# Q8                  Hisense 75-inch Q8 4K ULED Smart TV   75   3495
# Q950T            Samsung 85-inch Q950T 8K QLED Smart TV   85  12995
# P715            TCL 100-inch P715 QUHD LED LCD Smart TV  100  12995
#
#                                                     image
# model
# 65P615  https://media.binglee.com.au/media/catalog/pro...
# 75C815  https://media.binglee.com.au/media/catalog/pro...
# 40S4    https://media.binglee.com.au/media/catalog/pro...
# 49S4    https://media.binglee.com.au/media/catalog/pro...
# 40S615  https://media.binglee.com.au/media/catalog/pro...
# ...                                                   ...
# Nano91  https://azcd.harveynorman.com.au/media/catalog...
# Nano95  https://azcd.harveynorman.com.au/media/catalog...
# Q8      https://azcd.harveynorman.com.au/media/catalog...
# Q950T   https://azcd.harveynorman.com.au/media/catalog...
# P715    https://azcd.harveynorman.com.au/media/catalog...
#
# [284 rows x 8 columns]

# %%
convert_column_to_fk(tv_details,"category","output")
# Out:
#         retailer  category_id currency  brand  \
# model
# 65P615         1            1      AUD     15
# 75C815         1            1      AUD     15
# 40S4           1            1      AUD      7
# 49S4           1            1      AUD      7
# 40S615         1            1      AUD     15
# ...          ...          ...      ...    ...
# Nano91         3            1      AUD      9
# Nano95         3            1      AUD      9
# Q8             3            1      AUD      7
# Q950T          3            1      AUD     13
# P715           3            1      AUD     15
#
#                                                    name size  price  \
# model
# 65P615            TCL - 65P615 - 65" UHD 4K Android TV   65     995
# 75C815               TCL - 75C815 - 75” QLED Android TV   75   2995
# 40S4         Hisense - 40S4 - 40" Series 4 FHD Smart TV  40     495
# 49S4         Hisense - 49S4 - 49" Series 4 FHD Smart TV  49     595
# 40S615          TCL - 40S615 - 40” Full HD Android TV     40    495
# ...                                                 ...  ...    ...
# Nano91  LG 65-inch Nano91 4K NanoCell Ai ThinQ Smart TV   65   2695
# Nano95  LG 65-inch Nano95 8K NanoCell Ai ThinQ Smart TV   65   3995
# Q8                  Hisense 75-inch Q8 4K ULED Smart TV   75   3495
# Q950T            Samsung 85-inch Q950T 8K QLED Smart TV   85  12995
# P715            TCL 100-inch P715 QUHD LED LCD Smart TV  100  12995
#
#                                                     image
# model
# 65P615  https://media.binglee.com.au/media/catalog/pro...
# 75C815  https://media.binglee.com.au/media/catalog/pro...
# 40S4    https://media.binglee.com.au/media/catalog/pro...
# 49S4    https://media.binglee.com.au/media/catalog/pro...
# 40S615  https://media.binglee.com.au/media/catalog/pro...
# ...                                                   ...
# Nano91  https://azcd.harveynorman.com.au/media/catalog...
# Nano95  https://azcd.harveynorman.com.au/media/catalog...
# Q8      https://azcd.harveynorman.com.au/media/catalog...
# Q950T   https://azcd.harveynorman.com.au/media/catalog...
# P715    https://azcd.harveynorman.com.au/media/catalog...
#
# [284 rows x 8 columns]

# %%
# Creating new table for retailer and price 
retailer_price = tv_details[['retailer', 'price']].copy()
retailer_price.to_csv("output/retailer_price.csv")

# %%
# Dropping columns from product details dataframe
tv_details = tv_details.drop(['price'], axis=1)

# %%
tv_details = tv_details.drop(['retailer'], axis=1)

# %%
tv_details.drop_duplicates("model", inplace=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-55-0b8c9aab31dc> in <module>
# ----> 1 tv_details.drop_duplicates("model", inplace=True)
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/core/frame.py in drop_duplicates(self, subset, keep, inplace, ignore_index)
#    4809
#    4810         inplace = validate_bool_kwarg(inplace, "inplace")
# -> 4811         duplicated = self.duplicated(subset, keep=keep)
#    4812
#    4813         if inplace:
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/core/frame.py in duplicated(self, subset, keep)
#    4883         diff = Index(subset).difference(self.columns)
#    4884         if not diff.empty:
# -> 4885             raise KeyError(diff)
#    4886
#    4887         vals = (col.values for name, col in self.items() if name in subset)
#
# KeyError: Index(['model'], dtype='object')

# %%
tv_details.to_csv("output/product_details.csv")

# %% [markdown]
# ### Create database connection

# %%
connection_string = "postgres:Yas.123@localhost:5432/Television_database"
engine = create_engine(f'postgresql://{connection_string}')

# %%
# Test connection by confirming tables 
engine.table_names()
# Out:
# ['brand', 'category', 'product_details', 'retailer_price', 'retailer']

# %% [markdown]
# ### Load DataFrames into database

# %%
tv_details.to_sql(name='product_details', con=engine, if_exists='append', index=True)
# Out:
# ---------------------------------------------------------------------------
# UniqueViolation                           Traceback (most recent call last)
# ~/opt/anaconda3/lib/python3.7/site-packages/sqlalchemy/engine/base.py in _execute_context(self, dialect, constructor, statement, parameters, *args)
#    1225                     self.dialect.do_executemany(
# -> 1226                         cursor, statement, parameters, context
#    1227                     )
#
# ~/opt/anaconda3/lib/python3.7/site-packages/sqlalchemy/dialects/postgresql/psycopg2.py in do_executemany(self, cursor, statement, parameters, context)
#     853         if self.executemany_mode is EXECUTEMANY_DEFAULT:
# --> 854             cursor.executemany(statement, parameters)
#     855             return
#
# UniqueViolation: duplicate key value violates unique constraint "product_details_pkey"
# DETAIL:  Key (model)=(KDL32W660E) already exists.
#
#
# The above exception was the direct cause of the following exception:
#
# IntegrityError                            Traceback (most recent call last)
# <ipython-input-54-06a1c48a71ac> in <module>
# ----> 1 tv_details.to_sql(name='product_details', con=engine, if_exists='append', index=True)
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/core/generic.py in to_sql(self, name, con, schema, if_exists, index, index_label, chunksize, dtype, method)
#    2661             chunksize=chunksize,
#    2662             dtype=dtype,
# -> 2663             method=method,
#    2664         )
#    2665
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/io/sql.py in to_sql(frame, name, con, schema, if_exists, index, index_label, chunksize, dtype, method)
#     519         chunksize=chunksize,
#     520         dtype=dtype,
# --> 521         method=method,
#     522     )
#     523
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/io/sql.py in to_sql(self, frame, name, if_exists, index, index_label, schema, chunksize, dtype, method)
#    1315         )
#    1316         table.create()
# -> 1317         table.insert(chunksize, method=method)
#    1318         if not name.isdigit() and not name.islower():
#    1319             # check for potentially case sensitivity issues (GH7815)
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/io/sql.py in insert(self, chunksize, method)
#     753
#     754                 chunk_iter = zip(*[arr[start_i:end_i] for arr in data_list])
# --> 755                 exec_insert(conn, keys, chunk_iter)
#     756
#     757     def _query_iterator(
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/io/sql.py in _execute_insert(self, conn, keys, data_iter)
#     667         """
#     668         data = [dict(zip(keys, row)) for row in data_iter]
# --> 669         conn.execute(self.table.insert(), data)
#     670
#     671     def _execute_insert_multi(self, conn, keys, data_iter):
#
# ~/opt/anaconda3/lib/python3.7/site-packages/sqlalchemy/engine/base.py in execute(self, object_, *multiparams, **params)
#     980             raise exc.ObjectNotExecutableError(object_)
#     981         else:
# --> 982             return meth(self, multiparams, params)
#     983
#     984     def _execute_function(self, func, multiparams, params):
#
# ~/opt/anaconda3/lib/python3.7/site-packages/sqlalchemy/sql/elements.py in _execute_on_connection(self, connection, multiparams, params)
#     291     def _execute_on_connection(self, connection, multiparams, params):
#     292         if self.supports_execution:
# --> 293             return connection._execute_clauseelement(self, multiparams, params)
#     294         else:
#     295             raise exc.ObjectNotExecutableError(self)
#
# ~/opt/anaconda3/lib/python3.7/site-packages/sqlalchemy/engine/base.py in _execute_clauseelement(self, elem, multiparams, params)
#    1099             distilled_params,
#    1100             compiled_sql,
# -> 1101             distilled_params,
#    1102         )
#    1103         if self._has_events or self.engine._has_events:
#
# ~/opt/anaconda3/lib/python3.7/site-packages/sqlalchemy/engine/base.py in _execute_context(self, dialect, constructor, statement, parameters, *args)
#    1248         except BaseException as e:
#    1249             self._handle_dbapi_exception(
# -> 1250                 e, statement, parameters, cursor, context
#    1251             )
#    1252
#
# ~/opt/anaconda3/lib/python3.7/site-packages/sqlalchemy/engine/base.py in _handle_dbapi_exception(self, e, statement, parameters, cursor, context)
#    1474                 util.raise_from_cause(newraise, exc_info)
#    1475             elif should_wrap:
# -> 1476                 util.raise_from_cause(sqlalchemy_exception, exc_info)
#    1477             else:
#    1478                 util.reraise(*exc_info)
#
# ~/opt/anaconda3/lib/python3.7/site-packages/sqlalchemy/util/compat.py in raise_from_cause(exception, exc_info)
#     396     exc_type, exc_value, exc_tb = exc_info
#     397     cause = exc_value if exc_value is not exception else None
# --> 398     reraise(type(exception), exception, tb=exc_tb, cause=cause)
#     399
#     400
#
# ~/opt/anaconda3/lib/python3.7/site-packages/sqlalchemy/util/compat.py in reraise(tp, value, tb, cause)
#     150             value.__cause__ = cause
#     151         if value.__traceback__ is not tb:
# --> 152             raise value.with_traceback(tb)
#     153         raise value
#     154
#
# ~/opt/anaconda3/lib/python3.7/site-packages/sqlalchemy/engine/base.py in _execute_context(self, dialect, constructor, statement, parameters, *args)
#    1224                 if not evt_handled:
#    1225                     self.dialect.do_executemany(
# -> 1226                         cursor, statement, parameters, context
#    1227                     )
#    1228             elif not parameters and context.no_parameters:
#
# ~/opt/anaconda3/lib/python3.7/site-packages/sqlalchemy/dialects/postgresql/psycopg2.py in do_executemany(self, cursor, statement, parameters, context)
#     852     def do_executemany(self, cursor, statement, parameters, context=None):
#     853         if self.executemany_mode is EXECUTEMANY_DEFAULT:
# --> 854             cursor.executemany(statement, parameters)
#     855             return
#     856
#
# IntegrityError: (psycopg2.errors.UniqueViolation) duplicate key value violates unique constraint "product_details_pkey"
# DETAIL:  Key (model)=(KDL32W660E) already exists.
#
# [SQL: INSERT INTO product_details (model, category, currency, brand, name, size, image) VALUES (%(model)s, %(category)s, %(currency)s, %(brand)s, %(name)s, %(size)s, %(image)s)]
# [parameters: ({'model': '65P615', 'category': 1, 'currency': 'AUD', 'brand': 15, 'name': 'TCL - 65P615 - 65" UHD 4K Android TV ', 'size': '65 ', 'image': 'https://media.binglee.com.au/media/catalog/product/cache/1/small_image/185x185/9df78eab33525d08d6e5fb8d27136e95/t/c/tcl-p615-hero.jpg'}, {'model': '75C815', 'category': 1, 'currency': 'AUD', 'brand': 15, 'name': 'TCL - 75C815 - 75” QLED Android TV', 'size': '75', 'image': 'https://media.binglee.com.au/media/catalog/product/cache/1/small_image/185x185/9df78eab33525d08d6e5fb8d27136e95/7/5/75c815_01_med.jpg'}, {'model': '40S4', 'category': 1, 'currency': 'AUD', 'brand': 7, 'name': 'Hisense - 40S4 - 40" Series 4 FHD Smart TV', 'size': '40 ', 'image': 'https://media.binglee.com.au/media/catalog/product/cache/1/small_image/185x185/9df78eab33525d08d6e5fb8d27136e95/3/2/32s4-hero_2.jpg'}, {'model': '49S4', 'category': 1, 'currency': 'AUD', 'brand': 7, 'name': 'Hisense - 49S4 - 49" Series 4 FHD Smart TV', 'size': '49 ', 'image': 'https://media.binglee.com.au/media/catalog/product/cache/1/small_image/185x185/9df78eab33525d08d6e5fb8d27136e95/3/2/32s4-hero_1.jpg'}, {'model': '40S615', 'category': 1, 'currency': 'AUD', 'brand': 15, 'name': 'TCL - 40S615 - 40” Full HD Android TV  ', 'size': '40', 'image': 'https://media.binglee.com.au/media/catalog/product/cache/1/small_image/185x185/9df78eab33525d08d6e5fb8d27136e95/t/c/tcl-s615-hero.jpg'}, {'model': '32S4', 'category': 1, 'currency': 'AUD', 'brand': 7, 'name': 'Hisense - 32S4 - 32" Series 4 HD Smart TV', 'size': '32 ', 'image': 'https://media.binglee.com.au/media/catalog/product/cache/1/small_image/185x185/9df78eab33525d08d6e5fb8d27136e95/3/2/32s4-hero.jpg'}, {'model': 'UA75TU8000', 'category': 1, 'currency': 'AUD', 'brand': 13, 'name': 'Samsung UA75TU8000WXXY 75" Crystal UHD 4K Smart TV   ', 'size': '75 ', 'image': 'https://media.binglee.com.au/media/catalog/product/cache/1/small_image/185x185/9df78eab33525d08d6e5fb8d27136e95/s/a/samsung-ua50tu8000-hero1_4.jpg'}, {'model': 'U55H10', 'category': 1, 'currency': 'AUD', 'brand': 2, 'name': 'CHiQ - U55H10 - 55" 4K UHD Android TV ', 'size': '55 ', 'image': 'https://media.binglee.com.au/media/catalog/product/cache/1/small_image/185x185/9df78eab33525d08d6e5fb8d27136e95/c/h/chiq-u55h10-hero.jpg'}  ... displaying 10 of 284 total bound parameter sets ...  {'model': 'Q950T', 'category': 1, 'currency': 'AUD', 'brand': 13, 'name': 'Samsung 85-inch Q950T 8K QLED Smart TV', 'size': 85, 'image': 'https://azcd.harveynorman.com.au/media/catalog/product/cache/21/thumbnail/56x32/9df78eab33525d08d6e5fb8d27136e95/s/a/samsung-q950t-8k-qled-smart-tv-b.jpg'}, {'model': 'P715', 'category': 1, 'currency': 'AUD', 'brand': 15, 'name': 'TCL 100-inch P715 QUHD LED LCD Smart TV', 'size': 100, 'image': 'https://azcd.harveynorman.com.au/media/catalog/product/cache/21/thumbnail/56x32/9df78eab33525d08d6e5fb8d27136e95/8/5/85p715-tcl-85-inch-p715-quhd-led-lcd-smart-tv-00_1-b.jpg'})]
# (Background on this error at: http://sqlalche.me/e/gkpj)

# %%
retailer_price.to_sql(name='retailer_price', con=engine, if_exists='append', index=True)
# Out:
# ---------------------------------------------------------------------------
# ForeignKeyViolation                       Traceback (most recent call last)
# ~/opt/anaconda3/lib/python3.7/site-packages/sqlalchemy/engine/base.py in _execute_context(self, dialect, constructor, statement, parameters, *args)
#    1225                     self.dialect.do_executemany(
# -> 1226                         cursor, statement, parameters, context
#    1227                     )
#
# ~/opt/anaconda3/lib/python3.7/site-packages/sqlalchemy/dialects/postgresql/psycopg2.py in do_executemany(self, cursor, statement, parameters, context)
#     853         if self.executemany_mode is EXECUTEMANY_DEFAULT:
# --> 854             cursor.executemany(statement, parameters)
#     855             return
#
# ForeignKeyViolation: insert or update on table "retailer_price" violates foreign key constraint "retailer_price_model_fkey"
# DETAIL:  Key (model)=(65P615) is not present in table "product_details".
#
#
# The above exception was the direct cause of the following exception:
#
# IntegrityError                            Traceback (most recent call last)
# <ipython-input-58-aa5240e55839> in <module>
# ----> 1 retailer_price.to_sql(name='retailer_price', con=engine, if_exists='append', index=True)
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/core/generic.py in to_sql(self, name, con, schema, if_exists, index, index_label, chunksize, dtype, method)
#    2661             chunksize=chunksize,
#    2662             dtype=dtype,
# -> 2663             method=method,
#    2664         )
#    2665
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/io/sql.py in to_sql(frame, name, con, schema, if_exists, index, index_label, chunksize, dtype, method)
#     519         chunksize=chunksize,
#     520         dtype=dtype,
# --> 521         method=method,
#     522     )
#     523
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/io/sql.py in to_sql(self, frame, name, if_exists, index, index_label, schema, chunksize, dtype, method)
#    1315         )
#    1316         table.create()
# -> 1317         table.insert(chunksize, method=method)
#    1318         if not name.isdigit() and not name.islower():
#    1319             # check for potentially case sensitivity issues (GH7815)
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/io/sql.py in insert(self, chunksize, method)
#     753
#     754                 chunk_iter = zip(*[arr[start_i:end_i] for arr in data_list])
# --> 755                 exec_insert(conn, keys, chunk_iter)
#     756
#     757     def _query_iterator(
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/io/sql.py in _execute_insert(self, conn, keys, data_iter)
#     667         """
#     668         data = [dict(zip(keys, row)) for row in data_iter]
# --> 669         conn.execute(self.table.insert(), data)
#     670
#     671     def _execute_insert_multi(self, conn, keys, data_iter):
#
# ~/opt/anaconda3/lib/python3.7/site-packages/sqlalchemy/engine/base.py in execute(self, object_, *multiparams, **params)
#     980             raise exc.ObjectNotExecutableError(object_)
#     981         else:
# --> 982             return meth(self, multiparams, params)
#     983
#     984     def _execute_function(self, func, multiparams, params):
#
# ~/opt/anaconda3/lib/python3.7/site-packages/sqlalchemy/sql/elements.py in _execute_on_connection(self, connection, multiparams, params)
#     291     def _execute_on_connection(self, connection, multiparams, params):
#     292         if self.supports_execution:
# --> 293             return connection._execute_clauseelement(self, multiparams, params)
#     294         else:
#     295             raise exc.ObjectNotExecutableError(self)
#
# ~/opt/anaconda3/lib/python3.7/site-packages/sqlalchemy/engine/base.py in _execute_clauseelement(self, elem, multiparams, params)
#    1099             distilled_params,
#    1100             compiled_sql,
# -> 1101             distilled_params,
#    1102         )
#    1103         if self._has_events or self.engine._has_events:
#
# ~/opt/anaconda3/lib/python3.7/site-packages/sqlalchemy/engine/base.py in _execute_context(self, dialect, constructor, statement, parameters, *args)
#    1248         except BaseException as e:
#    1249             self._handle_dbapi_exception(
# -> 1250                 e, statement, parameters, cursor, context
#    1251             )
#    1252
#
# ~/opt/anaconda3/lib/python3.7/site-packages/sqlalchemy/engine/base.py in _handle_dbapi_exception(self, e, statement, parameters, cursor, context)
#    1474                 util.raise_from_cause(newraise, exc_info)
#    1475             elif should_wrap:
# -> 1476                 util.raise_from_cause(sqlalchemy_exception, exc_info)
#    1477             else:
#    1478                 util.reraise(*exc_info)
#
# ~/opt/anaconda3/lib/python3.7/site-packages/sqlalchemy/util/compat.py in raise_from_cause(exception, exc_info)
#     396     exc_type, exc_value, exc_tb = exc_info
#     397     cause = exc_value if exc_value is not exception else None
# --> 398     reraise(type(exception), exception, tb=exc_tb, cause=cause)
#     399
#     400
#
# ~/opt/anaconda3/lib/python3.7/site-packages/sqlalchemy/util/compat.py in reraise(tp, value, tb, cause)
#     150             value.__cause__ = cause
#     151         if value.__traceback__ is not tb:
# --> 152             raise value.with_traceback(tb)
#     153         raise value
#     154
#
# ~/opt/anaconda3/lib/python3.7/site-packages/sqlalchemy/engine/base.py in _execute_context(self, dialect, constructor, statement, parameters, *args)
#    1224                 if not evt_handled:
#    1225                     self.dialect.do_executemany(
# -> 1226                         cursor, statement, parameters, context
#    1227                     )
#    1228             elif not parameters and context.no_parameters:
#
# ~/opt/anaconda3/lib/python3.7/site-packages/sqlalchemy/dialects/postgresql/psycopg2.py in do_executemany(self, cursor, statement, parameters, context)
#     852     def do_executemany(self, cursor, statement, parameters, context=None):
#     853         if self.executemany_mode is EXECUTEMANY_DEFAULT:
# --> 854             cursor.executemany(statement, parameters)
#     855             return
#     856
#
# IntegrityError: (psycopg2.errors.ForeignKeyViolation) insert or update on table "retailer_price" violates foreign key constraint "retailer_price_model_fkey"
# DETAIL:  Key (model)=(65P615) is not present in table "product_details".
#
# [SQL: INSERT INTO retailer_price (model, retailer, price) VALUES (%(model)s, %(retailer)s, %(price)s)]
# [parameters: ({'model': '65P615', 'retailer': 1, 'price': 995.0}, {'model': '75C815', 'retailer': 1, 'price': 2995.0}, {'model': '40S4', 'retailer': 1, 'price': 495.0}, {'model': '49S4', 'retailer': 1, 'price': 595.0}, {'model': '40S615', 'retailer': 1, 'price': 495.0}, {'model': '32S4', 'retailer': 1, 'price': 375.0}, {'model': 'UA75TU8000', 'retailer': 1, 'price': 2295.0}, {'model': 'U55H10', 'retailer': 1, 'price': 695.0}  ... displaying 10 of 284 total bound parameter sets ...  {'model': 'Q950T', 'retailer': 3, 'price': 12995}, {'model': 'P715', 'retailer': 3, 'price': 12995})]
# (Background on this error at: http://sqlalche.me/e/gkpj)
